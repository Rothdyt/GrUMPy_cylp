# %%
import numpy as np
import math,sys
from random import seed
from random import randint
import matplotlib.pyplot as plt
import pandas as pd

import coinor.grumpy

from coinor.grumpy import GenerateRandomMIP
from coinor.grumpy import BBTree
from coinor.grumpy import MOST_FRACTIONAL, FIXED_BRANCHING, PSEUDOCOST_BRANCHING
from coinor.grumpy import DEPTH_FIRST, BEST_FIRST, BEST_ESTIMATE
from coinor.grumpy import INFINITY

project_dir = '../'
sys.path.append(project_dir)

from src.cylpBranchAndBound import RELIABILITY_BRANCHING, HYBRID
from src.cylpBranchAndBound import BranchAndBound

from pulp import LpVariable, lpSum, LpProblem, LpMaximize, LpConstraint,LpBinary
from pulp import LpStatus, value

# %%
def identity(n):
    m=[[0 for x in range(n)] for y in range(n)]
    for i in range(0,n):
        m[i][i] = 1
    return m

def negIdentity(n):
    m=[[0 for x in range(n)] for y in range(n)]
    for i in range(0,n):
        m[i][i] = -1
    return m

# %%
numVars = 40
numCons = 20
rand_seed = randint(1,200)
CONSTRAINTS, VARIABLES, OBJ, MAT, RHS = GenerateRandomMIP(numVars=numVars , numCons=numCons,rand_seed= rand_seed,density = 0.2)

# %%
I = identity(len(VARIABLES))
negI = negIdentity(len(VARIABLES))
RHS = RHS + [0]*len(VARIABLES) + [3]*len(VARIABLES)
for i in VARIABLES:
    MAT[i] = MAT[i] + negI[int(i[1:])]
    CONSTRAINTS.append('C'+str(len(CONSTRAINTS)))
for i in VARIABLES:
    MAT[i] = MAT[i] + I[int(i[1:])]
    CONSTRAINTS.append('C'+str(len(CONSTRAINTS)))

# %%
var   = LpVariable.dicts("", VARIABLES, 0, 3,cat = 'Integer')
numCons = len(CONSTRAINTS)
numVars = len(VARIABLES)
prob = LpProblem("relax", LpMaximize)
prob += lpSum([OBJ[i]*var[i] for i in VARIABLES]), "Objective"
for j in range(numCons):
    prob += (lpSum([MAT[i][j]*var[i] for i in VARIABLES])<=RHS[j],\
                 CONSTRAINTS[j])
prob.solve()
print(value(prob.objective))
# Out:
# 283.0

# %%
T = BBTree()
opt1, LB1 = coinor.grumpy.BranchAndBound(T, CONSTRAINTS, VARIABLES, OBJ,MAT, RHS,branch_strategy=PSEUDOCOST_BRANCHING,search_strategy=BEST_ESTIMATE,binary_vars = False)
# Out:
# ===========================================
# Starting Branch and Bound
# Pseudocost brancing
# Unknown search strategy Best Estimate
# ===========================================
#
# ----------------------------------------------------
#
# Node: 0, Depth: 0, LB: None
# LP Solved, status: Optimal, obj: 293.00393065
# Fractional solution:
# x1 = 2.5934712
# x2 = 0.14486617
# x3 = 3.0
# x6 = 3.0
# x7 = 1.5821915
# x9 = 0.59671139
# x14 = 3.0
# x15 = 1.6577788
# x16 = 2.583714
# x17 = 1.3360738
# x21 = 3.0
# x23 = 1.1105021
# x27 = 3.0
# x28 = 3.0
# x30 = 2.9252231
# x32 = 3.0
# x33 = 1.8318829
# x37 = 1.1666255
# x38 = 2.6684937
# x39 = 0.86398304
# adding root 0
# Branching on variable x9
#
# ----------------------------------------------------
#
# Node: 3, Depth: 1, LB: None
# Branching variables: x9
# LP Solved, status: Optimal, obj: 292.63814578
# Fractional solution:
# x1 = 2.7033094
# x2 = 0.19758852
# x3 = 3.0
# x6 = 3.0
# x7 = 1.7222222
# x9 = 1.0
# x14 = 3.0
# x15 = 0.55569898
# x16 = 2.537037
# x17 = 1.3111644
# x21 = 2.8133014
# x23 = 1.2059295
# x27 = 3.0
# x28 = 3.0
# x30 = 2.8373525
# x32 = 3.0
# x33 = 1.5209817
# x37 = 1.6303624
# x38 = 2.4444444
# x39 = 1.0495001
# Branching on variable x2
#
# ----------------------------------------------------
#
# Node: 4, Depth: 2, LB: None
# Branching variables: x2 x9
# LP Solved, status: Optimal, obj: 292.3299104
# Fractional solution:
# x1 = 2.7030696
# x3 = 3.0
# x6 = 3.0
# x7 = 1.7222222
# x9 = 1.0
# x14 = 3.0
# x15 = 0.11117645
# x16 = 2.537037
# x17 = 1.3061291
# x21 = 2.8163225
# x23 = 1.2055938
# x27 = 3.0
# x28 = 3.0
# x30 = 2.8375443
# x32 = 3.0
# x33 = 1.5215412
# x37 = 1.702939
# x38 = 2.4444444
# x39 = 1.3670137
# Branching on variable x15
#
# ----------------------------------------------------
#
# Node: 6, Depth: 3, LB: None
# Branching variables: x15 x2 x9
# LP Solved, status: Optimal, obj: 292.312509702
# Fractional solution:
# x1 = 2.7181474
# x3 = 3.0
# x6 = 3.0
# x7 = 1.7435294
# x9 = 1.0
# x14 = 3.0
# x16 = 2.5299347
# x17 = 1.3191356
# x20 = 0.030682302
# x21 = 2.8085186
# x23 = 1.2178247
# x27 = 3.0
# x28 = 3.0
# x30 = 2.8254821
# x32 = 3.0
# x33 = 1.520096
# x37 = 1.7537799
# x38 = 2.410353
# x39 = 1.3732382
# Branching on variable x20
#
# ----------------------------------------------------
#
# Node: 8, Depth: 4, LB: None
# Branching variables: x20 x15 x2 x9
# LP Solved, status: Optimal, obj: 292.301369286
# Fractional solution:
# x1 = 2.5740489
# x3 = 3.0
# x6 = 3.0
# x7 = 1.7277448
# x9 = 1.0
# x14 = 3.0
# x16 = 2.5318827
# x17 = 1.4422459
# x21 = 2.7346525
# x23 = 1.0572901
# x26 = 0.13832685
# x27 = 3.0
# x28 = 3.0
# x29 = 0.0099405686
# x30 = 2.9228678
# x32 = 3.0
# x33 = 1.5064171
# x37 = 1.539122
# x38 = 2.4356084
# x39 = 1.5186559
# Branching on variable x26
#
# ----------------------------------------------------
#
# Node: 9, Depth: 4, LB: None
# Branching variables: x20 x15 x2 x9
# LP Solved, status: Optimal, obj: 287.54119856
# Fractional solution:
# x1 = 2.9335429
# x3 = 3.0
# x6 = 3.0
# x7 = 2.0570056
# x9 = 1.0
# x14 = 3.0
# x16 = 2.4254426
# x17 = 1.3754046
# x20 = 1.0
# x21 = 2.7747572
# x22 = 0.56317187
# x23 = 1.3887633
# x27 = 3.0
# x28 = 2.2601257
# x30 = 2.6531657
# x32 = 3.0
# x33 = 1.5138439
# x37 = 1.9309825
# x38 = 1.9087911
# x39 = 0.82802647
# Branching on variable x22
#
# ----------------------------------------------------
#
# Node: 2, Depth: 1, LB: None
# Branching variables: x9
# LP Solved, status: Optimal, obj: 292.70573412999994
# Fractional solution:
# x0 = 0.13194444
# x1 = 2.5
# x2 = 0.1
# x3 = 3.0
# x6 = 3.0
# x7 = 1.375
# x14 = 2.7361302
# x15 = 2.9410461
# x16 = 2.6527778
# x17 = 1.7453704
# x21 = 3.0
# x23 = 1.0
# x27 = 3.0
# x28 = 3.0
# x30 = 3.0
# x32 = 3.0
# x33 = 2.2505144
# x37 = 0.67649231
# x38 = 3.0
# x39 = 0.59384232
# Branching on variable x37
#
# ----------------------------------------------------
#
# Node: 10, Depth: 5, LB: None
# Branching variables: x26 x20 x15 x2 x9
# LP Solved, status: Optimal, obj: 292.2994833
# Fractional solution:
# x1 = 2.6281264
# x3 = 3.0
# x6 = 3.0
# x7 = 1.7383872
# x9 = 1.0
# x14 = 3.0
# x16 = 2.5219497
# x17 = 1.3132589
# x21 = 2.8120447
# x23 = 1.1952924
# x27 = 3.0
# x28 = 3.0
# x29 = 0.02909701
# x30 = 2.8451243
# x32 = 3.0
# x33 = 1.520749
# x37 = 1.7451606
# x38 = 2.4185804
# x39 = 1.3921785
# Branching on variable x29
#
# ----------------------------------------------------
#
# Node: 16, Depth: 6, LB: None
# Branching variables: x29 x26 x20 x15 x2 x9
# LP Solved, status: Optimal, obj: 292.2818274
# Fractional solution:
# x1 = 2.7181474
# x3 = 3.0
# x6 = 3.0
# x7 = 1.7435294
# x9 = 1.0
# x14 = 3.0
# x16 = 2.5299347
# x17 = 1.3191356
# x21 = 2.8085186
# x23 = 1.2178247
# x27 = 3.0
# x28 = 3.0
# x30 = 2.8254821
# x32 = 3.0
# x33 = 1.520096
# x37 = 1.7537799
# x38 = 2.410353
# x39 = 1.3732382
# Branching on variable x39
#
# ----------------------------------------------------
#
# Node: 18, Depth: 7, LB: None
# Branching variables: x39 x29 x26 x20 x15 x2 x9
# LP Solved, status: Optimal, obj: 291.1215791999999
# Fractional solution:
# x1 = 2.7924228
# x3 = 3.0
# x6 = 3.0
# x7 = 1.844861
# x9 = 1.0
# x14 = 3.0
# x16 = 2.4961574
# x17 = 1.4349432
# x21 = 2.7390341
# x23 = 1.2795888
# x27 = 3.0
# x28 = 3.0
# x30 = 2.7660617
# x32 = 3.0
# x33 = 1.5072285
# x37 = 1.923631
# x38 = 2.2482224
# x39 = 1.0
# Branching on variable x33
#
# ----------------------------------------------------
#
# Node: 7, Depth: 3, LB: None
# Branching variables: x15 x2 x9
# LP Solved, status: Optimal, obj: 291.48681281999995
# Fractional solution:
# x1 = 2.7073885
# x3 = 3.0
# x6 = 3.0
# x7 = 1.7222222
# x9 = 1.0
# x14 = 3.0
# x15 = 1.0
# x16 = 2.537037
# x17 = 1.3968254
# x21 = 2.7619048
# x22 = 0.18073123
# x23 = 1.2116402
# x27 = 3.0
# x28 = 3.0
# x30 = 2.8340892
# x32 = 3.0
# x33 = 1.5114638
# x37 = 1.3410356
# x38 = 2.4444444
# x39 = 1.111521
# Branching on variable x22
#
# ----------------------------------------------------
#
# Node: 22, Depth: 4, LB: None
# Branching variables: x22 x15 x2 x9
# LP Solved, status: Optimal, obj: 291.36364810000003
# Fractional solution:
# x1 = 2.8144885
# x3 = 3.0
# x6 = 3.0
# x7 = 1.7222222
# x9 = 1.0
# x14 = 3.0
# x15 = 1.0
# x16 = 2.537037
# x17 = 1.3968254
# x21 = 2.7619048
# x23 = 1.3615802
# x27 = 3.0
# x28 = 3.0
# x30 = 2.7484092
# x32 = 2.80722
# x33 = 1.5757238
# x37 = 1.5820106
# x38 = 2.4444444
# x39 = 1.0753748
# Branching on variable x39
#
# ----------------------------------------------------
#
# Node: 24, Depth: 5, LB: None
# Branching variables: x39 x22 x15 x2 x9
# LP Solved, status: Optimal, obj: 291.24639929999995
# Fractional solution:
# x1 = 2.7935511
# x3 = 3.0
# x6 = 3.0
# x7 = 1.7222222
# x9 = 1.0
# x14 = 3.0
# x15 = 1.0
# x16 = 2.537037
# x17 = 1.3968254
# x21 = 2.7619048
# x23 = 1.3322678
# x27 = 3.0
# x28 = 3.0
# x30 = 2.7651592
# x32 = 2.8449074
# x33 = 1.5631614
# x37 = 1.5820106
# x38 = 2.4444444
# x39 = 1.0
# Branching on variable x33
#
# ----------------------------------------------------
#
# Node: 15, Depth: 2, LB: None
# Branching variables: x37 x9
# LP Solved, status: Optimal, obj: 292.62275864
# Fractional solution:
# x1 = 2.5600323
# x2 = 0.12881552
# x3 = 3.0
# x6 = 3.0
# x7 = 1.5329131
# x14 = 2.7567272
# x15 = 2.2633051
# x16 = 2.6001401
# x17 = 1.8333333
# x21 = 3.0
# x23 = 1.0842203
# x27 = 3.0
# x28 = 3.0
# x30 = 2.9519741
# x32 = 3.0
# x33 = 2.2407407
# x37 = 1.0
# x38 = 2.747339
# x39 = 0.58701003
# Branching on variable x39
#
# ----------------------------------------------------
#
# Node: 28, Depth: 3, LB: None
# Branching variables: x39 x37 x9
# LP Solved, status: Optimal, obj: 291.78654616
# Fractional solution:
# x0 = 1.0451028
# x1 = 3.0
# x2 = 0.50367441
# x3 = 3.0
# x6 = 3.0
# x7 = 1.5409534
# x14 = 3.0
# x15 = 2.844285
# x16 = 2.6253965
# x17 = 1.1365981
# x21 = 3.0
# x23 = 1.058337
# x27 = 2.9497143
# x28 = 2.7576927
# x30 = 2.6502857
# x32 = 3.0
# x33 = 2.3181558
# x37 = 1.0
# x38 = 2.8249889
# Branching on variable x2
#
# ----------------------------------------------------
#
# Node: 30, Depth: 4, LB: None
# Branching variables: x2 x39 x37 x9
# LP Solved, status: Optimal, obj: 290.86629640999996
# Fractional solution:
# x1 = 2.6055556
# x3 = 3.0
# x6 = 3.0
# x7 = 1.6
# x14 = 2.8533333
# x15 = 2.8
# x16 = 2.5777778
# x17 = 1.8333333
# x20 = 0.16740741
# x21 = 3.0
# x23 = 1.12
# x27 = 3.0
# x28 = 3.0
# x30 = 2.9155556
# x32 = 3.0
# x33 = 2.2407407
# x37 = 1.0
# x38 = 2.64
# Branching on variable x20
#
# ----------------------------------------------------
#
# Node: 29, Depth: 3, LB: None
# Branching variables: x39 x37 x9
# LP Solved, status: Optimal, obj: 292.42062761
# Fractional solution:
# x1 = 2.5117512
# x3 = 2.9282763
# x6 = 3.0
# x7 = 1.5853183
# x14 = 2.8357153
# x15 = 1.6261403
# x16 = 2.5826717
# x17 = 1.8333333
# x21 = 3.0
# x23 = 0.99479131
# x26 = 0.10564058
# x27 = 3.0
# x28 = 3.0
# x30 = 2.990599
# x32 = 3.0
# x33 = 2.2805873
# x37 = 1.0
# x38 = 2.6634908
# x39 = 1.0
# Branching on variable x23
#
# ----------------------------------------------------
#
# Node: 35, Depth: 4, LB: None
# Branching variables: x23 x39 x37 x9
# LP Solved, status: Optimal, obj: 292.415900547
# Fractional solution:
# x1 = 2.5130687
# x3 = 2.9215528
# x6 = 3.0
# x7 = 1.5772443
# x14 = 2.8260264
# x15 = 1.6471816
# x16 = 2.585363
# x17 = 1.8333333
# x20 = 0.010217495
# x21 = 3.0
# x23 = 1.0
# x26 = 0.097077244
# x27 = 3.0
# x28 = 3.0
# x30 = 2.989545
# x32 = 3.0
# x33 = 2.2843225
# x37 = 1.0
# x38 = 2.6764092
# x39 = 1.0
# Branching on variable x20
#
# ----------------------------------------------------
#
# Node: 36, Depth: 5, LB: None
# Branching variables: x20 x23 x39 x37 x9
# LP Solved, status: Optimal, obj: 292.405683052
# Fractional solution:
# x1 = 2.5130687
# x3 = 2.9215528
# x6 = 3.0
# x7 = 1.5772443
# x14 = 2.8260264
# x15 = 1.6471816
# x16 = 2.585363
# x17 = 1.8333333
# x21 = 3.0
# x23 = 1.0
# x26 = 0.097077244
# x27 = 3.0
# x28 = 3.0
# x30 = 2.989545
# x32 = 3.0
# x33 = 2.2843225
# x37 = 1.0
# x38 = 2.6764092
# x39 = 1.0
# Branching on variable x26
#
# ----------------------------------------------------
#
# Node: 38, Depth: 6, LB: None
# Branching variables: x26 x20 x23 x39 x37 x9
# LP Solved, status: Optimal, obj: 292.29473687
# Fractional solution:
# x1 = 2.3136861
# x3 = 2.8966153
# x6 = 3.0
# x7 = 1.4785077
# x13 = 0.025223033
# x14 = 2.722256
# x15 = 1.8280616
# x16 = 2.5906732
# x17 = 1.8039065
# x21 = 3.0
# x23 = 1.0
# x27 = 3.0
# x28 = 3.0
# x29 = 0.082806164
# x30 = 3.0
# x32 = 3.0
# x33 = 2.3014463
# x37 = 1.0
# x38 = 2.8343877
# x39 = 1.0
# Branching on variable x13
#
# ----------------------------------------------------
#
# Node: 40, Depth: 7, LB: None
# Branching variables: x13 x26 x20 x23 x39 x37 x9
# LP Solved, status: Optimal, obj: 292.26927727
# Fractional solution:
# x1 = 2.3703041
# x3 = 2.8957328
# x6 = 3.0
# x7 = 1.535995
# x14 = 2.7105339
# x15 = 1.8480038
# x16 = 2.5980038
# x17 = 1.8333333
# x21 = 3.0
# x23 = 1.0
# x27 = 2.951116
# x28 = 3.0
# x29 = 0.084800377
# x30 = 3.0
# x32 = 3.0
# x33 = 2.2986669
# x37 = 1.0
# x38 = 2.8303992
# x39 = 1.0
# Branching on variable x29
#
# ----------------------------------------------------
#
# Node: 42, Depth: 8, LB: None
# Branching variables: x29 x13 x26 x20 x23 x39 x37 x9
# LP Solved, status: Optimal, obj: 292.196159965
# Fractional solution:
# x1 = 2.5
# x3 = 2.8961754
# x6 = 3.0
# x7 = 1.4857143
# x14 = 2.7161905
# x15 = 1.8857143
# x16 = 2.615873
# x17 = 1.8333333
# x18 = 0.013227513
# x21 = 3.0
# x23 = 1.0
# x27 = 3.0
# x28 = 3.0
# x30 = 3.0
# x32 = 3.0
# x33 = 2.288133
# x37 = 1.0
# x38 = 2.8228571
# x39 = 1.0
# Branching on variable x18
#
# ----------------------------------------------------
#
# Node: 44, Depth: 9, LB: None
# Branching variables: x18 x29 x13 x26 x20 x23 x39 x37 x9
# LP Solved, status: Optimal, obj: 292.18337440000005
# Fractional solution:
# x1 = 2.5252016
# x3 = 2.892884
# x6 = 3.0
# x7 = 1.5064516
# x14 = 2.7138575
# x15 = 1.8701613
# x16 = 2.6201613
# x17 = 1.8333333
# x21 = 3.0
# x23 = 1.0
# x27 = 2.9798387
# x28 = 3.0
# x30 = 3.0
# x32 = 3.0
# x33 = 2.3002496
# x37 = 1.0
# x38 = 2.8259677
# x39 = 1.0
# Branching on variable x15
#
# ----------------------------------------------------
#
# Node: 46, Depth: 10, LB: None
# Branching variables: x15 x18 x29 x13 x26 x20 x23 x39 x37 x9
# LP Solved, status: Optimal, obj: 291.23909195780004
# Fractional solution:
# x1 = 3.0
# x2 = 0.0041152263
# x3 = 3.0
# x6 = 3.0
# x7 = 1.685607
# x14 = 2.5828189
# x15 = 1.0
# x16 = 2.7026283
# x17 = 1.8333333
# x21 = 3.0
# x23 = 1.0
# x27 = 2.7239049
# x28 = 3.0
# x30 = 2.8760951
# x32 = 3.0
# x33 = 2.2407407
# x37 = 1.0
# x38 = 3.0
# x39 = 1.0
# Branching on variable x2
#
# ----------------------------------------------------
#
# Node: 47, Depth: 10, LB: None
# Branching variables: x15 x18 x29 x13 x26 x20 x23 x39 x37 x9
# LP Solved, status: Optimal, obj: 291.79523824
# Fractional solution:
# x0 = 0.16666667
# x1 = 2.5
# x3 = 2.8698413
# x6 = 3.0
# x7 = 1.3333333
# x14 = 2.7888889
# x15 = 2.0
# x16 = 2.6666667
# x17 = 1.7222222
# x21 = 3.0
# x23 = 1.0
# x27 = 3.0
# x28 = 3.0
# x30 = 3.0
# x32 = 3.0
# x33 = 2.3253968
# x37 = 1.0
# x38 = 2.8
# x39 = 1.0
# Branching on variable x0
#
# ----------------------------------------------------
#
# Node: 50, Depth: 11, LB: None
# Branching variables: x0 x15 x18 x29 x13 x26 x20 x23 x39 x37 x9
# LP Solved, status: Optimal, obj: 291.74908878639997
# Fractional solution:
# x1 = 2.5
# x3 = 2.8654762
# x4 = 0.0098039216
# x6 = 3.0
# x7 = 1.5
# x14 = 2.7333333
# x15 = 2.0
# x16 = 2.6078431
# x17 = 1.8333333
# x21 = 3.0
# x23 = 1.0
# x27 = 3.0
# x28 = 3.0
# x30 = 3.0
# x32 = 2.9375
# x33 = 2.3363095
# x37 = 1.0
# x38 = 2.8
# x39 = 1.0
# Branching on variable x4
#
# ----------------------------------------------------
#
# Node: 52, Depth: 12, LB: None
# Branching variables: x4 x0 x15 x18 x29 x13 x26 x20 x23 x39 x37 x9
# LP Solved, status: Optimal, obj: 291.74177993160004
# Fractional solution:
# x1 = 2.4960317
# x3 = 2.8651361
# x6 = 3.0
# x7 = 1.5
# x14 = 2.7333333
# x15 = 2.0
# x16 = 2.6111111
# x17 = 1.8333333
# x21 = 3.0
# x23 = 1.0
# x27 = 3.0
# x28 = 3.0
# x30 = 3.0
# x32 = 2.9355159
# x33 = 2.3371599
# x35 = 0.0079365079
# x37 = 1.0
# x38 = 2.8
# x39 = 1.0
# Branching on variable x35
#
# ----------------------------------------------------
#
# Node: 54, Depth: 13, LB: None
# Branching variables: x35 x4 x0 x15 x18 x29 x13 x26 x20 x23 x39 x37 x9
# LP Solved, status: Optimal, obj: 291.73928509999996
# Fractional solution:
# x1 = 2.5
# x3 = 2.8654762
# x6 = 3.0
# x7 = 1.5
# x14 = 2.7333333
# x15 = 2.0
# x16 = 2.6111111
# x17 = 1.8333333
# x21 = 3.0
# x23 = 1.0
# x27 = 3.0
# x28 = 3.0
# x30 = 3.0
# x32 = 2.9375
# x33 = 2.3363095
# x37 = 1.0
# x38 = 2.8
# x39 = 1.0
# Branching on variable x7
#
# ----------------------------------------------------
#
# Node: 48, Depth: 11, LB: None
# Branching variables: x2 x15 x18 x29 x13 x26 x20 x23 x39 x37 x9
# LP Solved, status: Optimal, obj: 291.2190302
# Fractional solution:
# x1 = 3.0
# x3 = 3.0
# x6 = 3.0
# x7 = 1.685607
# x14 = 2.5833333
# x15 = 1.0
# x16 = 2.7026283
# x17 = 1.8333333
# x21 = 3.0
# x23 = 1.0
# x27 = 2.7239049
# x28 = 3.0
# x30 = 2.8760951
# x32 = 3.0
# x33 = 2.2407407
# x37 = 1.0
# x38 = 3.0
# x39 = 1.0
# Branching on variable x33
#
# ----------------------------------------------------
#
# Node: 32, Depth: 5, LB: None
# Branching variables: x20 x2 x39 x37 x9
# LP Solved, status: Optimal, obj: 290.698889
# Fractional solution:
# x1 = 2.6055556
# x3 = 3.0
# x6 = 3.0
# x7 = 1.6
# x14 = 2.8533333
# x15 = 2.8
# x16 = 2.5777778
# x17 = 1.8333333
# x21 = 3.0
# x23 = 1.12
# x27 = 3.0
# x28 = 3.0
# x30 = 2.9155556
# x32 = 3.0
# x33 = 2.2407407
# x37 = 1.0
# x38 = 2.64
# Branching on variable x23
#
# ----------------------------------------------------
#
# Node: 58, Depth: 12, LB: None
# Branching variables: x33 x2 x15 x18 x29 x13 x26 x20 x23 x39 x37 x9
# LP Solved, status: Optimal, obj: 290.49680809999995
# Fractional solution:
# x1 = 3.0
# x3 = 3.0
# x6 = 3.0
# x7 = 1.685607
# x14 = 2.5833333
# x15 = 1.0
# x16 = 2.7026283
# x17 = 1.8333333
# x21 = 3.0
# x23 = 1.0
# x27 = 2.7239049
# x28 = 3.0
# x30 = 2.8760951
# x32 = 3.0
# x33 = 2.0
# x37 = 1.0
# x38 = 3.0
# x39 = 1.0
# Branching on variable x7
#
# ----------------------------------------------------
#
# Node: 51, Depth: 11, LB: None
# Branching variables: x0 x15 x18 x29 x13 x26 x20 x23 x39 x37 x9
# LP Solved, status: Optimal, obj: 291.34446834
# Fractional solution:
# x0 = 1.0
# x1 = 2.797619
# x2 = 0.24285714
# x3 = 2.5597694
# x6 = 3.0
# x7 = 1.3333333
# x14 = 3.0
# x15 = 2.0
# x16 = 2.6666667
# x17 = 1.2138219
# x21 = 2.9717069
# x23 = 1.0
# x27 = 3.0
# x28 = 3.0
# x30 = 2.7619048
# x32 = 3.0
# x33 = 2.5541479
# x37 = 1.0
# x38 = 2.8169759
# x39 = 1.0
# Branching on variable x2
#
# ----------------------------------------------------
#
# Node: 64, Depth: 12, LB: None
# Branching variables: x2 x0 x15 x18 x29 x13 x26 x20 x23 x39 x37 x9
# LP Solved, status: Optimal, obj: 291.3382499
# Fractional solution:
# x0 = 1.0
# x1 = 2.797619
# x3 = 2.8430427
# x6 = 3.0
# x7 = 1.3333333
# x14 = 3.0
# x15 = 2.0
# x16 = 2.6666667
# x17 = 1.2532468
# x21 = 2.9480519
# x23 = 1.0
# x27 = 3.0
# x28 = 3.0
# x30 = 2.7619048
# x32 = 3.0
# x33 = 2.3923933
# x37 = 1.0
# x38 = 2.8311688
# x39 = 1.0
# Branching on variable x17
#
# ----------------------------------------------------
#
# Node: 27, Depth: 6, LB: None
# Branching variables: x33 x39 x22 x15 x2 x9
# LP Solved, status: Optimal, obj: 287.83905809999993
# Fractional solution:
# x1 = 2.7935511
# x3 = 2.2136905
# x6 = 3.0
# x7 = 1.7222222
# x9 = 1.0
# x14 = 3.0
# x15 = 1.0
# x16 = 2.537037
# x17 = 1.3968254
# x21 = 2.7619048
# x23 = 1.3322678
# x27 = 3.0
# x28 = 3.0
# x30 = 2.7651592
# x32 = 2.8449074
# x33 = 2.0
# x37 = 1.5820106
# x38 = 2.4444444
# x39 = 1.0
# Branching on variable x37
#
# ----------------------------------------------------
#
# Node: 61, Depth: 6, LB: None
# Branching variables: x23 x20 x2 x39 x37 x9
# LP Solved, status: Optimal, obj: 284.39652967999996
# Fractional solution:
# x1 = 3.0
# x3 = 2.6965986
# x6 = 3.0
# x7 = 1.7222222
# x14 = 3.0
# x15 = 3.0
# x16 = 2.1583333
# x17 = 1.8333333
# x21 = 3.0
# x23 = 2.0
# x27 = 3.0
# x28 = 3.0
# x30 = 2.6
# x32 = 1.952381
# x33 = 2.7585034
# x34 = 0.34083333
# x37 = 1.0
# x38 = 2.4444444
# Branching on variable x34
#
# ----------------------------------------------------
#
# Node: 60, Depth: 6, LB: None
# Branching variables: x23 x20 x2 x39 x37 x9
# LP Solved, status: Optimal, obj: 290.367422856
# Fractional solution:
# x0 = 0.027777778
# x1 = 2.21875
# x3 = 3.0
# x6 = 3.0
# x7 = 1.6
# x14 = 2.8625926
# x15 = 2.8
# x16 = 2.5361111
# x17 = 1.8148148
# x21 = 3.0
# x23 = 1.0
# x27 = 3.0
# x28 = 3.0
# x29 = 0.125
# x30 = 3.0
# x32 = 3.0
# x33 = 2.2427984
# x37 = 1.0
# x38 = 2.64
# Branching on variable x29
#
# ----------------------------------------------------
#
# Node: 72, Depth: 7, LB: None
# Branching variables: x29 x23 x20 x2 x39 x37 x9
# LP Solved, status: Optimal, obj: 290.31707253999997
# Fractional solution:
# x1 = 2.555359
# x3 = 3.0
# x6 = 3.0
# x7 = 1.7193396
# x14 = 2.9965409
# x15 = 2.4889937
# x16 = 2.5379979
# x17 = 1.8333333
# x21 = 3.0
# x23 = 1.0
# x26 = 0.12657233
# x27 = 3.0
# x28 = 3.0
# x30 = 2.9557128
# x32 = 3.0
# x33 = 2.2407407
# x37 = 1.0
# x38 = 2.4490566
# Branching on variable x26
#
# ----------------------------------------------------
#
# Node: 74, Depth: 8, LB: None
# Branching variables: x26 x29 x23 x20 x2 x39 x37 x9
# LP Solved, status: Optimal, obj: 290.2188887
# Fractional solution:
# x1 = 2.5198413
# x3 = 3.0
# x6 = 3.0
# x7 = 1.6
# x14 = 2.8533333
# x15 = 2.8
# x16 = 2.5777778
# x17 = 1.8333333
# x21 = 3.0
# x23 = 1.0
# x27 = 3.0
# x28 = 3.0
# x30 = 2.984127
# x32 = 3.0
# x33 = 2.2407407
# x37 = 1.0
# x38 = 2.64
# Branching on variable x7
#
# ----------------------------------------------------
#
# Node: 66, Depth: 13, LB: None
# Branching variables: x17 x2 x0 x15 x18 x29 x13 x26 x20 x23 x39 x37 x9
# LP Solved, status: Optimal, obj: 290.5904762
# Fractional solution:
# x0 = 1.0
# x1 = 2.797619
# x3 = 2.8285714
# x6 = 3.0
# x7 = 1.3333333
# x14 = 3.0
# x15 = 2.0
# x16 = 2.6666667
# x17 = 1.0
# x21 = 3.0
# x23 = 1.0
# x27 = 3.0
# x28 = 2.75
# x30 = 2.7619048
# x32 = 3.0
# x33 = 2.4285714
# x37 = 1.0
# x38 = 3.0
# x39 = 1.0
# Branching on variable x7
#
# ----------------------------------------------------
#
# Node: 19, Depth: 7, LB: None
# Branching variables: x39 x29 x26 x20 x15 x2 x9
# LP Solved, status: Optimal, obj: 290.6729049
# Fractional solution:
# x1 = 2.7137188
# x3 = 2.4458844
# x6 = 3.0
# x7 = 1.7222222
# x9 = 1.0
# x14 = 3.0
# x16 = 2.537037
# x17 = 1.5297619
# x21 = 2.6821429
# x23 = 1.2205026
# x27 = 3.0
# x28 = 3.0
# x30 = 2.8290249
# x32 = 3.0
# x33 = 1.8045351
# x37 = 1.4047619
# x38 = 2.4444444
# x39 = 2.0
# Branching on variable x37
#
# ----------------------------------------------------
#
# Node: 81, Depth: 8, LB: None
# Branching variables: x37 x39 x29 x26 x20 x15 x2 x9
# LP Solved, status: Optimal, obj: 288.19544952
# Fractional solution:
# x1 = 2.5
# x3 = 2.2977627
# x6 = 3.0
# x7 = 0.60529666
# x9 = 1.0
# x14 = 3.0
# x16 = 2.9093456
# x17 = 1.487013
# x21 = 2.7077922
# x23 = 1.3866819
# x27 = 3.0
# x28 = 3.0
# x30 = 3.0
# x32 = 2.8980138
# x33 = 1.9255702
# x37 = 2.0
# x38 = 2.1753247
# x39 = 2.0
# Branching on variable x7
#
# ----------------------------------------------------
#
# Node: 21, Depth: 8, LB: None
# Branching variables: x33 x39 x29 x26 x20 x15 x2 x9
# LP Solved, status: Optimal, obj: 287.27796209999997
# Fractional solution:
# x1 = 2.7924228
# x3 = 2.1130114
# x6 = 3.0
# x7 = 1.844861
# x9 = 1.0
# x14 = 3.0
# x16 = 2.4961574
# x17 = 1.4349432
# x21 = 2.7390341
# x23 = 1.2795888
# x27 = 3.0
# x28 = 3.0
# x30 = 2.7660617
# x32 = 3.0
# x33 = 2.0
# x37 = 1.923631
# x38 = 2.2482224
# x39 = 1.0
# Branching on variable x23
#
# ----------------------------------------------------
#
# Node: 20, Depth: 8, LB: None
# Branching variables: x33 x39 x29 x26 x20 x15 x2 x9
# LP Solved, status: Optimal, obj: 289.59989369999994
# Fractional solution:
# x1 = 2.7924228
# x3 = 3.0
# x6 = 3.0
# x7 = 1.844861
# x9 = 1.0
# x14 = 3.0
# x16 = 2.4961574
# x17 = 1.4349432
# x21 = 2.7390341
# x23 = 1.2795888
# x27 = 3.0
# x28 = 3.0
# x30 = 2.7660617
# x32 = 3.0
# x33 = 1.0
# x37 = 1.923631
# x38 = 2.2482224
# x39 = 1.0
# Branching on variable x23
#
# ----------------------------------------------------
#
# Node: 26, Depth: 6, LB: None
# Branching variables: x33 x39 x22 x15 x2 x9
# LP Solved, status: Optimal, obj: 289.5839932
# Fractional solution:
# x1 = 2.7137188
# x3 = 3.0
# x6 = 3.0
# x7 = 1.7222222
# x9 = 1.0
# x14 = 3.0
# x15 = 1.0
# x16 = 2.537037
# x17 = 1.5297619
# x21 = 2.6821429
# x23 = 1.2205026
# x27 = 3.0
# x28 = 3.0
# x30 = 2.8290249
# x32 = 3.0
# x33 = 1.0
# x37 = 1.4047619
# x38 = 2.4444444
# x39 = 1.0
# Branching on variable x23
#
# ----------------------------------------------------
#
# Node: 88, Depth: 7, LB: None
# Branching variables: x23 x33 x39 x22 x15 x2 x9
# LP Solved, status: Optimal, obj: 289.19273912
# Fractional solution:
# x1 = 2.5451653
# x3 = 3.0
# x6 = 3.0
# x7 = 1.6850887
# x9 = 1.0
# x14 = 3.0
# x15 = 1.0
# x16 = 2.5494149
# x17 = 1.5657986
# x21 = 2.6605209
# x23 = 1.0
# x26 = 0.18279049
# x27 = 3.0
# x28 = 2.9236111
# x30 = 2.9638678
# x32 = 3.0
# x33 = 1.0
# x37 = 1.2378858
# x38 = 2.5038581
# x39 = 1.0
# Branching on variable x26
#
# ----------------------------------------------------
#
# Node: 90, Depth: 8, LB: None
# Branching variables: x26 x23 x33 x39 x22 x15 x2 x9
# LP Solved, status: Optimal, obj: 288.70198369999997
# Fractional solution:
# x1 = 2.5562169
# x3 = 3.0
# x6 = 3.0
# x7 = 1.7222222
# x9 = 1.0
# x14 = 3.0
# x15 = 1.0
# x16 = 2.537037
# x17 = 1.5297619
# x21 = 2.6821429
# x23 = 1.0
# x27 = 3.0
# x28 = 3.0
# x30 = 2.9550265
# x32 = 3.0
# x33 = 1.0
# x37 = 1.4047619
# x38 = 2.4444444
# x39 = 1.0
# Branching on variable x37
#
# ----------------------------------------------------
#
# Node: 59, Depth: 12, LB: None
# Branching variables: x33 x2 x15 x18 x29 x13 x26 x20 x23 x39 x37 x9
# LP Solved, status: Optimal, obj: 285.6319145
# Fractional solution:
# x0 = 1.25
# x1 = 3.0
# x3 = 1.8
# x6 = 3.0
# x7 = 1.4321652
# x14 = 3.0
# x15 = 1.0
# x16 = 2.6619524
# x17 = 1.0
# x21 = 3.0
# x23 = 1.0
# x27 = 2.9491865
# x28 = 3.0
# x30 = 2.6508135
# x32 = 3.0
# x33 = 3.0
# x37 = 1.0
# x38 = 3.0
# x39 = 1.0
# Branching on variable x0
#
# ----------------------------------------------------
#
# Node: 86, Depth: 9, LB: None
# Branching variables: x23 x33 x39 x29 x26 x20 x15 x2 x9
# LP Solved, status: Optimal, obj: 288.6434033
# Fractional solution:
# x1 = 2.9999494
# x3 = 3.0
# x6 = 3.0
# x7 = 1.7587563
# x9 = 1.0
# x13 = 0.10571746
# x14 = 3.0
# x16 = 2.524859
# x17 = 1.3138841
# x18 = 0.26304536
# x21 = 2.7376673
# x23 = 1.0
# x27 = 3.0
# x28 = 3.0
# x30 = 2.6000405
# x32 = 3.0
# x33 = 1.0
# x37 = 1.8095081
# x38 = 2.3859899
# x39 = 1.0
# Branching on variable x18
#
# ----------------------------------------------------
#
# Node: 31, Depth: 4, LB: None
# Branching variables: x2 x39 x37 x9
# LP Solved, status: Optimal, obj: 288.98868124
# Fractional solution:
# x0 = 1.5319444
# x1 = 3.0
# x2 = 1.0
# x3 = 2.4361343
# x6 = 3.0
# x7 = 1.375
# x14 = 2.9689815
# x15 = 2.96875
# x16 = 2.6527778
# x17 = 0.81203704
# x21 = 3.0
# x23 = 1.0
# x27 = 3.0
# x28 = 2.175
# x30 = 2.6
# x32 = 3.0
# x33 = 2.6674769
# x37 = 1.0
# x38 = 3.0
# Branching on variable x17
#
# ----------------------------------------------------
#
# Node: 96, Depth: 10, LB: None
# Branching variables: x18 x23 x33 x39 x29 x26 x20 x15 x2 x9
# LP Solved, status: Optimal, obj: 288.53326671
# Fractional solution:
# x1 = 2.6294407
# x3 = 3.0
# x6 = 3.0
# x7 = 1.7222222
# x9 = 1.0
# x13 = 0.051256614
# x14 = 3.0
# x16 = 2.537037
# x17 = 0.94328704
# x19 = 0.23835979
# x21 = 2.9981481
# x23 = 1.0
# x27 = 3.0
# x28 = 3.0
# x30 = 2.8964475
# x32 = 3.0
# x33 = 1.0
# x37 = 1.6305556
# x38 = 2.4444444
# x39 = 1.0
# Branching on variable x19
#
# ----------------------------------------------------
#
# Node: 63, Depth: 13, LB: None
# Branching variables: x7 x33 x2 x15 x18 x29 x13 x26 x20 x23 x39 x37 x9
# LP Solved, status: Optimal, obj: 289.9599995
# Fractional solution:
# x1 = 3.0
# x3 = 3.0
# x6 = 3.0
# x7 = 2.0
# x12 = 0.12
# x14 = 2.7933333
# x15 = 1.0
# x16 = 2.25
# x17 = 1.8333333
# x21 = 3.0
# x23 = 1.0
# x27 = 2.6
# x28 = 3.0
# x30 = 3.0
# x32 = 3.0
# x33 = 2.0
# x34 = 0.375
# x37 = 1.0
# x38 = 2.72
# x39 = 1.0
# Branching on variable x34
#
# ----------------------------------------------------
#
# Node: 78, Depth: 14, LB: None
# Branching variables: x7 x17 x2 x0 x15 x18 x29 x13 x26 x20 x23 x39 x37 x9
# LP Solved, status: Optimal, obj: 289.763809102
# Fractional solution:
# x0 = 1.0
# x1 = 2.6984127
# x3 = 2.8285714
# x5 = 0.06
# x6 = 3.0
# x7 = 1.0
# x14 = 3.0
# x15 = 2.0
# x16 = 2.7777778
# x17 = 1.0
# x19 = 0.085714286
# x21 = 3.0
# x23 = 1.0
# x27 = 3.0
# x28 = 3.0
# x30 = 2.8412698
# x32 = 3.0
# x33 = 2.4285714
# x37 = 1.0
# x38 = 2.8
# x39 = 1.0
# Branching on variable x19
#
# ----------------------------------------------------
#
# Node: 104, Depth: 15, LB: None
# Branching variables: x19 x7 x17 x2 x0 x15 x18 x29 x13 x26 x20 x23 x39 x37 x9
# LP Solved, status: Optimal, obj: 289.67380909999997
# Fractional solution:
# x0 = 1.0
# x1 = 2.6984127
# x3 = 2.8285714
# x6 = 3.0
# x7 = 1.0
# x14 = 3.0
# x15 = 2.0
# x16 = 2.7777778
# x17 = 1.0
# x21 = 3.0
# x23 = 1.0
# x27 = 3.0
# x28 = 2.75
# x30 = 2.8412698
# x32 = 3.0
# x33 = 2.4285714
# x37 = 1.0
# x38 = 3.0
# x39 = 1.0
# Branching on variable x1
#
# ----------------------------------------------------
#
# Node: 107, Depth: 16, LB: None
# Branching variables: x1 x19 x7 x17 x2 x0 x15 x18 x29 x13 x26 x20 x23 x39 x37 x9
# LP Solved, status: Optimal, obj: 289.139673
# Fractional solution:
# x0 = 1.0
# x1 = 3.0
# x3 = 2.8285714
# x6 = 3.0
# x7 = 1.0
# x14 = 3.0
# x15 = 2.0
# x16 = 2.8795181
# x17 = 1.0
# x21 = 3.0
# x23 = 1.0
# x27 = 2.8168675
# x28 = 2.75
# x30 = 2.7831325
# x32 = 3.0
# x33 = 2.4285714
# x37 = 1.0
# x38 = 3.0
# x39 = 1.0
# Branching on variable x28
#
# ----------------------------------------------------
#
# Node: 56, Depth: 14, LB: None
# Branching variables: x7 x35 x4 x0 x15 x18 x29 x13 x26 x20 x23 x39 x37 x9
# LP Solved, status: Optimal, obj: 290.371428386
# Fractional solution:
# x1 = 2.5
# x3 = 2.8761905
# x6 = 3.0
# x7 = 1.0
# x12 = 0.085714286
# x14 = 2.7333333
# x15 = 2.0
# x16 = 2.7777778
# x17 = 1.8333333
# x21 = 3.0
# x23 = 1.0
# x27 = 3.0
# x28 = 3.0
# x30 = 3.0
# x32 = 3.0
# x33 = 2.3095238
# x37 = 1.0
# x38 = 2.8
# x39 = 1.0
# Branching on variable x12
#
# ----------------------------------------------------
#
# Node: 110, Depth: 15, LB: None
# Branching variables: x12 x7 x35 x4 x0 x15 x18 x29 x13 x26 x20 x23 x39 x37 x9
# LP Solved, status: Optimal, obj: 290.2857141
# Fractional solution:
# x1 = 2.5
# x3 = 2.8761905
# x6 = 3.0
# x7 = 1.0
# x14 = 2.7333333
# x15 = 2.0
# x16 = 2.7777778
# x17 = 1.8333333
# x21 = 3.0
# x23 = 1.0
# x27 = 3.0
# x28 = 3.0
# x30 = 3.0
# x32 = 3.0
# x33 = 2.3095238
# x37 = 1.0
# x38 = 2.8
# x39 = 1.0
# Branching on variable x1
#
# ----------------------------------------------------
#
# Node: 111, Depth: 15, LB: None
# Branching variables: x12 x7 x35 x4 x0 x15 x18 x29 x13 x26 x20 x23 x39 x37 x9
# LP Solved, status: Optimal, obj: 281.44999959999996
# Fractional solution:
# x1 = 2.5
# x3 = 2.6833333
# x6 = 3.0
# x7 = 1.0
# x12 = 1.0
# x14 = 2.7333333
# x15 = 2.0
# x16 = 2.7777778
# x17 = 1.8333333
# x21 = 3.0
# x23 = 1.0
# x27 = 3.0
# x28 = 3.0
# x30 = 3.0
# x32 = 1.875
# x33 = 2.7916667
# x37 = 1.0
# x38 = 2.8
# x39 = 1.0
# Branching on variable x1
#
# ----------------------------------------------------
#
# Node: 113, Depth: 16, LB: None
# Branching variables: x1 x12 x7 x35 x4 x0 x15 x18 x29 x13 x26 x20 x23 x39 x37 x9
# LP Solved, status: Optimal, obj: 289.7857139
# Fractional solution:
# x1 = 3.0
# x3 = 2.8761905
# x6 = 3.0
# x7 = 1.0
# x14 = 2.7333333
# x15 = 2.0
# x16 = 3.0
# x17 = 1.8333333
# x21 = 3.0
# x23 = 1.0
# x27 = 2.6
# x28 = 3.0
# x30 = 3.0
# x32 = 3.0
# x33 = 2.3095238
# x37 = 1.0
# x38 = 2.8
# x39 = 1.0
# Branching on variable x17
#
# ----------------------------------------------------
#
# Node: 112, Depth: 16, LB: None
# Branching variables: x1 x12 x7 x35 x4 x0 x15 x18 x29 x13 x26 x20 x23 x39 x37 x9
# LP Solved, status: Optimal, obj: 289.73888827999997
# Fractional solution:
# x1 = 2.0
# x3 = 2.8333333
# x6 = 3.0
# x7 = 1.0
# x10 = 0.125
# x14 = 2.7333333
# x15 = 2.0
# x16 = 2.7777778
# x17 = 1.8333333
# x21 = 3.0
# x23 = 1.0
# x25 = 0.11111111
# x27 = 3.0
# x28 = 3.0
# x30 = 3.0
# x32 = 3.0
# x33 = 2.3333333
# x37 = 1.0
# x38 = 2.8
# x39 = 1.0
# Branching on variable x25
#
# ----------------------------------------------------
#
# Node: 118, Depth: 17, LB: None
# Branching variables: x25 x1 x12 x7 x35 x4 x0 x15 x18 x29 x13 x26 x20 x23 x39 x37 x9
# LP Solved, status: Optimal, obj: 289.36402136000004
# Fractional solution:
# x1 = 2.0
# x3 = 2.8733686
# x6 = 3.0
# x7 = 1.0
# x10 = 0.17592593
# x14 = 2.7580247
# x15 = 2.0
# x16 = 2.7777778
# x17 = 1.7839506
# x21 = 3.0
# x23 = 1.0
# x27 = 3.0
# x28 = 3.0
# x30 = 3.0
# x31 = 0.14814815
# x32 = 3.0
# x33 = 2.3165785
# x37 = 1.0
# x38 = 2.8
# x39 = 1.0
# Branching on variable x10
#
# ----------------------------------------------------
#
# Node: 120, Depth: 18, LB: None
# Branching variables: x10 x25 x1 x12 x7 x35 x4 x0 x15 x18 x29 x13 x26 x20 x23 x39 x37 x9
# LP Solved, status: Optimal, obj: 289.0121695
# Fractional solution:
# x1 = 2.0
# x3 = 2.8733686
# x6 = 3.0
# x7 = 1.0
# x14 = 2.7580247
# x15 = 2.0
# x16 = 2.7777778
# x17 = 1.7839506
# x21 = 3.0
# x23 = 1.0
# x27 = 3.0
# x28 = 3.0
# x30 = 3.0
# x31 = 0.14814815
# x32 = 3.0
# x33 = 2.3165785
# x37 = 1.0
# x38 = 2.8
# x39 = 1.0
# Branching on variable x31
#
# ----------------------------------------------------
#
# Node: 117, Depth: 17, LB: None
# Branching variables: x17 x1 x12 x7 x35 x4 x0 x15 x18 x29 x13 x26 x20 x23 x39 x37 x9
# LP Solved, status: Optimal, obj: 289.61642870000003
# Fractional solution:
# x1 = 3.0
# x3 = 2.8857143
# x6 = 3.0
# x7 = 1.0
# x14 = 2.605
# x15 = 2.0
# x16 = 3.0
# x17 = 2.0
# x21 = 2.9
# x23 = 1.0
# x27 = 2.6
# x28 = 3.0
# x30 = 3.0
# x32 = 3.0
# x33 = 2.2857143
# x37 = 1.0
# x38 = 2.86
# x39 = 1.0
# Branching on variable x3
#
# ----------------------------------------------------
#
# Node: 125, Depth: 18, LB: None
# Branching variables: x3 x17 x1 x12 x7 x35 x4 x0 x15 x18 x29 x13 x26 x20 x23 x39 x37 x9
# LP Solved, status: Optimal, obj: 289.44500000000005
# Fractional solution:
# x1 = 3.0
# x3 = 3.0
# x6 = 3.0
# x7 = 1.0
# x14 = 2.605
# x15 = 2.0
# x16 = 3.0
# x17 = 2.0
# x21 = 2.9
# x23 = 1.0
# x27 = 2.6
# x28 = 3.0
# x30 = 3.0
# x32 = 3.0
# x33 = 2.0
# x37 = 1.0
# x38 = 2.86
# x39 = 1.0
# Branching on variable x21
#
# ----------------------------------------------------
#
# Node: 127, Depth: 19, LB: None
# Branching variables: x21 x3 x17 x1 x12 x7 x35 x4 x0 x15 x18 x29 x13 x26 x20 x23 x39 x37 x9
# LP Solved, status: Infeasible
# Infeasible node
#
# ----------------------------------------------------
#
# Node: 122, Depth: 19, LB: None
# Branching variables: x31 x10 x25 x1 x12 x7 x35 x4 x0 x15 x18 x29 x13 x26 x20 x23 x39 x37 x9
# LP Solved, status: Optimal, obj: 288.7857141
# Fractional solution:
# x1 = 2.0
# x3 = 2.8761905
# x6 = 3.0
# x7 = 1.0
# x14 = 2.7333333
# x15 = 2.0
# x16 = 2.7777778
# x17 = 1.8333333
# x21 = 3.0
# x23 = 1.0
# x27 = 3.0
# x28 = 3.0
# x30 = 3.0
# x32 = 3.0
# x33 = 2.3095238
# x37 = 1.0
# x38 = 2.8
# x39 = 1.0
# Branching on variable x3
#
# ----------------------------------------------------
#
# Node: 129, Depth: 20, LB: None
# Branching variables: x3 x31 x10 x25 x1 x12 x7 x35 x4 x0 x15 x18 x29 x13 x26 x20 x23 x39 x37 x9
# LP Solved, status: Optimal, obj: 288.5999997
# Fractional solution:
# x1 = 2.0
# x3 = 3.0
# x6 = 3.0
# x7 = 1.0
# x14 = 2.7333333
# x15 = 2.0
# x16 = 2.7777778
# x17 = 1.8333333
# x21 = 3.0
# x23 = 1.0
# x27 = 3.0
# x28 = 3.0
# x30 = 3.0
# x32 = 3.0
# x33 = 2.0
# x37 = 1.0
# x38 = 2.8
# x39 = 1.0
# Branching on variable x17
#
# ----------------------------------------------------
#
# Node: 57, Depth: 14, LB: None
# Branching variables: x7 x35 x4 x0 x15 x18 x29 x13 x26 x20 x23 x39 x37 x9
# LP Solved, status: Optimal, obj: 289.844444276
# Fractional solution:
# x1 = 3.0
# x3 = 2.8333333
# x6 = 3.0
# x7 = 2.0
# x10 = 0.027777778
# x14 = 2.7333333
# x15 = 2.0
# x16 = 2.25
# x17 = 1.8333333
# x21 = 3.0
# x23 = 1.0
# x27 = 2.5555556
# x28 = 3.0
# x30 = 3.0
# x32 = 2.75
# x33 = 2.4166667
# x34 = 0.39722222
# x37 = 1.0
# x38 = 2.8
# x39 = 1.0
# Branching on variable x34
#
# ----------------------------------------------------
#
# Node: 23, Depth: 4, LB: None
# Branching variables: x22 x15 x2 x9
# LP Solved, status: Optimal, obj: 286.38126386
# Fractional solution:
# x1 = 3.0
# x3 = 3.0
# x6 = 3.0
# x7 = 2.4787905
# x9 = 1.0
# x14 = 3.0
# x15 = 1.0
# x16 = 2.2553916
# x17 = 2.2614748
# x20 = 0.40527003
# x21 = 2.2431151
# x22 = 1.0
# x23 = 1.6138746
# x27 = 3.0
# x28 = 3.0
# x29 = 0.088367963
# x30 = 2.4409377
# x32 = 3.0
# x33 = 1.4153917
# x37 = 1.5168297
# x38 = 1.2339352
# x39 = 0.2364551
# Branching on variable x39
#
# ----------------------------------------------------
#
# Node: 14, Depth: 2, LB: None
# Branching variables: x37 x9
# LP Solved, status: Optimal, obj: 291.7406520899999
# Fractional solution:
# x1 = 3.0
# x3 = 3.0
# x6 = 3.0
# x7 = 1.6558723
# x13 = 0.12857458
# x14 = 3.0
# x15 = 3.0
# x16 = 2.6978561
# x17 = 1.6833297
# x19 = 0.03809734
# x21 = 3.0
# x23 = 0.81617807
# x26 = 0.1387716
# x27 = 2.7503357
# x28 = 3.0
# x30 = 2.8496643
# x32 = 3.0
# x33 = 2.2574078
# x38 = 3.0
# x39 = 0.86761433
# Branching on variable x39
#
# ----------------------------------------------------
#
# Node: 136, Depth: 3, LB: None
# Branching variables: x39 x37 x9
# LP Solved, status: Optimal, obj: 289.41296786
# Fractional solution:
# x1 = 3.0
# x2 = 0.23460145
# x3 = 3.0
# x6 = 3.0
# x7 = 1.375
# x10 = 0.11948973
# x13 = 0.55027174
# x14 = 3.0
# x15 = 3.0
# x16 = 2.6527778
# x17 = 1.1913496
# x21 = 3.0
# x22 = 0.5
# x23 = 1.0
# x27 = 3.0
# x28 = 3.0
# x30 = 2.4088164
# x32 = 3.0
# x33 = 2.3120723
# x38 = 3.0
# Branching on variable x13
#
# ----------------------------------------------------
#
# Node: 137, Depth: 3, LB: None
# Branching variables: x39 x37 x9
# LP Solved, status: Optimal, obj: 291.718835971
# Fractional solution:
# x1 = 3.0
# x3 = 2.8695114
# x6 = 3.0
# x7 = 1.6815309
# x13 = 0.087825136
# x14 = 3.0
# x15 = 3.0
# x16 = 2.7019741
# x17 = 1.7308707
# x19 = 0.010931043
# x21 = 3.0
# x23 = 0.83440163
# x26 = 0.1413868
# x27 = 2.7275281
# x28 = 3.0
# x30 = 2.8724719
# x32 = 3.0
# x33 = 2.3246192
# x38 = 3.0
# x39 = 1.0
# Branching on variable x23
#
# ----------------------------------------------------
#
# Node: 141, Depth: 4, LB: None
# Branching variables: x23 x39 x37 x9
# LP Solved, status: Optimal, obj: 290.7496659032
# Fractional solution:
# x1 = 3.0
# x2 = 0.17265124
# x3 = 2.5406085
# x6 = 3.0
# x7 = 1.4846586
# x13 = 0.24777431
# x14 = 3.0
# x15 = 3.0
# x16 = 2.6703773
# x17 = 1.7068372
# x21 = 2.9024557
# x23 = 1.0
# x26 = 0.0097544329
# x27 = 2.9025257
# x28 = 3.0
# x30 = 2.6974743
# x32 = 3.0
# x33 = 2.5100133
# x38 = 3.0
# x39 = 1.0
# Branching on variable x2
#
# ----------------------------------------------------
#
# Node: 142, Depth: 5, LB: None
# Branching variables: x2 x23 x39 x37 x9
# LP Solved, status: Optimal, obj: 290.6995675
# Fractional solution:
# x1 = 3.0
# x3 = 2.7428571
# x6 = 3.0
# x7 = 1.4864834
# x13 = 0.24552428
# x14 = 3.0
# x15 = 3.0
# x16 = 2.6706702
# x17 = 1.75
# x21 = 2.878133
# x23 = 1.0
# x26 = 0.0121867
# x27 = 2.9009036
# x28 = 3.0
# x30 = 2.6990964
# x32 = 3.0
# x33 = 2.3928571
# x38 = 3.0
# x39 = 1.0
# Branching on variable x13
#
# ----------------------------------------------------
#
# Node: 144, Depth: 6, LB: None
# Branching variables: x13 x2 x23 x39 x37 x9
# LP Solved, status: Optimal, obj: 290.597718936
# Fractional solution:
# x1 = 3.0
# x3 = 2.747619
# x6 = 3.0
# x7 = 1.7144625
# x14 = 3.0
# x15 = 3.0
# x16 = 2.6901126
# x17 = 1.8333333
# x20 = 0.05
# x21 = 3.0
# x23 = 1.0
# x26 = 0.016666667
# x27 = 2.7291197
# x28 = 3.0
# x30 = 2.8708803
# x32 = 3.0
# x33 = 2.3809524
# x38 = 2.9444444
# x39 = 1.0
# Branching on variable x20
#
# ----------------------------------------------------
#
# Node: 146, Depth: 7, LB: None
# Branching variables: x20 x13 x2 x23 x39 x37 x9
# LP Solved, status: Optimal, obj: 290.54771893599997
# Fractional solution:
# x1 = 3.0
# x3 = 2.747619
# x6 = 3.0
# x7 = 1.7144625
# x14 = 3.0
# x15 = 3.0
# x16 = 2.6901126
# x17 = 1.8333333
# x21 = 3.0
# x23 = 1.0
# x26 = 0.016666667
# x27 = 2.7291197
# x28 = 3.0
# x30 = 2.8708803
# x32 = 3.0
# x33 = 2.3809524
# x38 = 2.9444444
# x39 = 1.0
# Branching on variable x26
#
# ----------------------------------------------------
#
# Node: 148, Depth: 8, LB: None
# Branching variables: x26 x20 x13 x2 x23 x39 x37 x9
# LP Solved, status: Optimal, obj: 290.5003793
# Fractional solution:
# x1 = 3.0
# x3 = 2.747619
# x6 = 3.0
# x7 = 1.685607
# x14 = 2.9583333
# x15 = 3.0
# x16 = 2.7026283
# x17 = 1.8333333
# x21 = 3.0
# x23 = 1.0
# x27 = 2.7239049
# x28 = 3.0
# x30 = 2.8760951
# x32 = 3.0
# x33 = 2.3809524
# x38 = 3.0
# x39 = 1.0
# Branching on variable x3
#
# ----------------------------------------------------
#
# Node: 151, Depth: 9, LB: None
# Branching variables: x3 x26 x20 x13 x2 x23 x39 x37 x9
# LP Solved, status: Optimal, obj: 290.1218081
# Fractional solution:
# x1 = 3.0
# x3 = 3.0
# x6 = 3.0
# x7 = 1.685607
# x14 = 2.9583333
# x15 = 3.0
# x16 = 2.7026283
# x17 = 1.8333333
# x21 = 3.0
# x23 = 1.0
# x27 = 2.7239049
# x28 = 3.0
# x30 = 2.8760951
# x32 = 3.0
# x33 = 1.75
# x38 = 3.0
# x39 = 1.0
# Branching on variable x7
#
# ----------------------------------------------------
#
# Node: 140, Depth: 4, LB: None
# Branching variables: x23 x39 x37 x9
# LP Solved, status: Optimal, obj: 288.006205314
# Fractional solution:
# x0 = 0.43973693
# x1 = 3.0
# x2 = 0.072482559
# x3 = 3.0
# x6 = 3.0
# x7 = 1.5672832
# x14 = 3.0
# x15 = 3.0
# x16 = 2.683638
# x17 = 1.5401754
# x18 = 0.71461598
# x21 = 3.0
# x22 = 0.19170398
# x26 = 0.32830721
# x27 = 2.8290816
# x28 = 2.795824
# x30 = 2.7709184
# x32 = 3.0
# x33 = 1.7175014
# x38 = 3.0
# x39 = 1.0
# Branching on variable x18
#
# ----------------------------------------------------
#
# Node: 153, Depth: 10, LB: None
# Branching variables: x7 x3 x26 x20 x13 x2 x23 x39 x37 x9
# LP Solved, status: Optimal, obj: 289.67139868
# Fractional solution:
# x1 = 3.0
# x3 = 3.0
# x6 = 3.0
# x7 = 2.0
# x14 = 3.0
# x15 = 3.0
# x16 = 2.25
# x17 = 1.8982614
# x21 = 2.9610431
# x23 = 1.0
# x27 = 2.4993561
# x28 = 3.0
# x29 = 0.055913286
# x30 = 3.0
# x32 = 3.0
# x33 = 1.75
# x34 = 0.40854797
# x38 = 2.901159
# x39 = 1.0
# Branching on variable x34
#
# ----------------------------------------------------
#
# Node: 138, Depth: 4, LB: None
# Branching variables: x13 x39 x37 x9
# LP Solved, status: Optimal, obj: 288.4871034
# Fractional solution:
# x0 = 0.19842486
# x1 = 3.0
# x2 = 0.19579963
# x3 = 3.0
# x6 = 3.0
# x7 = 1.6453757
# x14 = 3.0
# x15 = 3.0
# x16 = 2.6961714
# x17 = 1.7010501
# x21 = 3.0
# x23 = 1.0
# x27 = 2.7596661
# x28 = 3.0
# x30 = 2.8403339
# x32 = 3.0
# x33 = 2.2554389
# x38 = 3.0
# Branching on variable x2
#
# ----------------------------------------------------
#
# Node: 152, Depth: 10, LB: None
# Branching variables: x7 x3 x26 x20 x13 x2 x23 x39 x37 x9
# LP Solved, status: Optimal, obj: 288.728174864
# Fractional solution:
# x0 = 0.125
# x1 = 2.4543651
# x3 = 3.0
# x6 = 3.0
# x7 = 1.0
# x14 = 3.0
# x15 = 3.0
# x16 = 2.7777778
# x17 = 1.75
# x21 = 3.0
# x23 = 1.0
# x27 = 3.0
# x28 = 3.0
# x30 = 3.0
# x32 = 3.0
# x33 = 1.75
# x35 = 0.091269841
# x38 = 3.0
# x39 = 1.0
# Branching on variable x0
#
# ----------------------------------------------------
#
# Node: 160, Depth: 11, LB: None
# Branching variables: x0 x7 x3 x26 x20 x13 x2 x23 x39 x37 x9
# LP Solved, status: Optimal, obj: 288.69245992
# Fractional solution:
# x1 = 2.4365079
# x3 = 3.0
# x6 = 3.0
# x7 = 1.0
# x14 = 2.9583333
# x15 = 3.0
# x16 = 2.7777778
# x17 = 1.8333333
# x21 = 3.0
# x23 = 1.0
# x27 = 3.0
# x28 = 3.0
# x30 = 3.0
# x32 = 3.0
# x33 = 1.75
# x35 = 0.12698413
# x38 = 3.0
# x39 = 1.0
# Branching on variable x35
#
# ----------------------------------------------------
#
# Node: 162, Depth: 12, LB: None
# Branching variables: x35 x0 x7 x3 x26 x20 x13 x2 x23 x39 x37 x9
# LP Solved, status: Optimal, obj: 288.5318623
# Fractional solution:
# x1 = 2.5
# x3 = 3.0
# x4 = 0.15686275
# x6 = 3.0
# x7 = 1.0
# x14 = 2.9583333
# x15 = 3.0
# x16 = 2.7254902
# x17 = 1.8333333
# x21 = 3.0
# x23 = 1.0
# x27 = 3.0
# x28 = 3.0
# x30 = 3.0
# x32 = 3.0
# x33 = 1.75
# x38 = 3.0
# x39 = 1.0
# Branching on variable x4
#
# ----------------------------------------------------
#
# Node: 164, Depth: 13, LB: None
# Branching variables: x4 x35 x0 x7 x3 x26 x20 x13 x2 x23 x39 x37 x9
# LP Solved, status: Optimal, obj: 288.3749997
# Fractional solution:
# x1 = 2.5
# x3 = 3.0
# x6 = 3.0
# x7 = 1.0
# x14 = 2.9583333
# x15 = 3.0
# x16 = 2.7777778
# x17 = 1.8333333
# x21 = 3.0
# x23 = 1.0
# x27 = 3.0
# x28 = 3.0
# x30 = 3.0
# x32 = 3.0
# x33 = 1.75
# x38 = 3.0
# x39 = 1.0
# Branching on variable x1
#
# ----------------------------------------------------
#
# Node: 158, Depth: 5, LB: None
# Branching variables: x2 x13 x39 x37 x9
# LP Solved, status: Optimal, obj: 288.11154388
# Fractional solution:
# x1 = 3.0
# x3 = 3.0
# x6 = 3.0
# x7 = 1.7728781
# x14 = 3.0
# x15 = 3.0
# x16 = 2.699488
# x17 = 1.8333333
# x21 = 3.0
# x23 = 0.85594424
# x26 = 0.14631685
# x27 = 2.6771948
# x28 = 3.0
# x30 = 2.9228052
# x32 = 3.0
# x33 = 2.2407407
# x38 = 2.9444444
# Branching on variable x23
#
# ----------------------------------------------------
#
# Node: 167, Depth: 14, LB: None
# Branching variables: x1 x4 x35 x0 x7 x3 x26 x20 x13 x2 x23 x39 x37 x9
# LP Solved, status: Optimal, obj: 287.8749995
# Fractional solution:
# x1 = 3.0
# x3 = 3.0
# x6 = 3.0
# x7 = 1.0
# x14 = 2.9583333
# x15 = 3.0
# x16 = 3.0
# x17 = 1.8333333
# x21 = 3.0
# x23 = 1.0
# x27 = 2.6
# x28 = 3.0
# x30 = 3.0
# x32 = 3.0
# x33 = 1.75
# x38 = 3.0
# x39 = 1.0
# Branching on variable x17
#
# ----------------------------------------------------
#
# Node: 109, Depth: 17, LB: None
# Branching variables: x28 x1 x19 x7 x17 x2 x0 x15 x18 x29 x13 x26 x20 x23 x39 x37 x9
# LP Solved, status: Optimal, obj: 288.955387286
# Fractional solution:
# x0 = 1.0
# x1 = 3.0
# x3 = 2.8285714
# x5 = 0.12
# x6 = 3.0
# x7 = 1.0
# x12 = 0.085714286
# x14 = 3.0
# x15 = 2.0
# x16 = 2.8795181
# x17 = 1.0
# x21 = 3.0
# x23 = 1.0
# x27 = 2.8168675
# x28 = 3.0
# x30 = 2.7831325
# x32 = 3.0
# x33 = 2.4285714
# x37 = 1.0
# x38 = 2.8
# x39 = 1.0
# Branching on variable x5
#
# ----------------------------------------------------
#
# Node: 172, Depth: 18, LB: None
# Branching variables: x5 x28 x1 x19 x7 x17 x2 x0 x15 x18 x29 x13 x26 x20 x23 x39 x37 x9
# LP Solved, status: Optimal, obj: 288.669534826
# Fractional solution:
# x0 = 1.0
# x1 = 3.0
# x3 = 2.8285714
# x6 = 3.0
# x7 = 1.0
# x8 = 0.17142857
# x12 = 0.085714286
# x14 = 3.0
# x15 = 2.0
# x16 = 2.858864
# x17 = 1.0
# x21 = 3.0
# x23 = 1.0
# x27 = 2.8540448
# x28 = 3.0
# x30 = 2.7459552
# x32 = 3.0
# x33 = 2.4285714
# x37 = 1.0
# x38 = 2.8
# x39 = 1.0
# Branching on variable x8
#
# ----------------------------------------------------
#
# Node: 174, Depth: 19, LB: None
# Branching variables: x8 x5 x28 x1 x19 x7 x17 x2 x0 x15 x18 x29 x13 x26 x20 x23 x39 x37 x9
# LP Solved, status: Optimal, obj: 288.475387286
# Fractional solution:
# x0 = 1.0
# x1 = 3.0
# x3 = 2.8285714
# x6 = 3.0
# x7 = 1.0
# x12 = 0.085714286
# x14 = 3.0
# x15 = 2.0
# x16 = 2.8795181
# x17 = 1.0
# x21 = 3.0
# x23 = 1.0
# x27 = 2.8168675
# x28 = 3.0
# x30 = 2.7831325
# x32 = 3.0
# x33 = 2.4285714
# x37 = 1.0
# x38 = 2.8
# x39 = 1.0
# Branching on variable x12
#
# ----------------------------------------------------
#
# Node: 176, Depth: 20, LB: None
# Branching variables: x12 x8 x5 x28 x1 x19 x7 x17 x2 x0 x15 x18 x29 x13 x26 x20 x23 x39 x37 x9
# LP Solved, status: Optimal, obj: 288.389673
# Fractional solution:
# x0 = 1.0
# x1 = 3.0
# x3 = 2.8285714
# x6 = 3.0
# x7 = 1.0
# x14 = 3.0
# x15 = 2.0
# x16 = 2.8795181
# x17 = 1.0
# x21 = 3.0
# x23 = 1.0
# x27 = 2.8168675
# x28 = 3.0
# x30 = 2.7831325
# x32 = 3.0
# x33 = 2.4285714
# x37 = 1.0
# x38 = 2.8
# x39 = 1.0
# Branching on variable x3
#
# ----------------------------------------------------
#
# Node: 179, Depth: 21, LB: None
# Branching variables: x3 x12 x8 x5 x28 x1 x19 x7 x17 x2 x0 x15 x18 x29 x13 x26 x20 x23 x39 x37 x9
# LP Solved, status: Optimal, obj: 288.1325304
# Fractional solution:
# x0 = 1.0
# x1 = 3.0
# x3 = 3.0
# x6 = 3.0
# x7 = 1.0
# x14 = 3.0
# x15 = 2.0
# x16 = 2.8795181
# x17 = 1.0
# x21 = 3.0
# x23 = 1.0
# x27 = 2.8168675
# x28 = 3.0
# x30 = 2.7831325
# x32 = 3.0
# x33 = 2.0
# x37 = 1.0
# x38 = 2.8
# x39 = 1.0
# Branching on variable x30
#
# ----------------------------------------------------
#
# Node: 99, Depth: 5, LB: None
# Branching variables: x17 x2 x39 x37 x9
# LP Solved, status: Optimal, obj: 288.95572593
# Fractional solution:
# x0 = 1.25
# x1 = 3.0
# x2 = 1.0
# x3 = 2.6973295
# x6 = 3.0
# x7 = 1.375
# x14 = 2.875
# x15 = 2.96875
# x16 = 2.6527778
# x17 = 1.0
# x18 = 0.23068182
# x21 = 3.0
# x23 = 0.79494949
# x27 = 3.0
# x28 = 2.175
# x30 = 2.6
# x32 = 3.0
# x33 = 2.3220644
# x37 = 1.0
# x38 = 3.0
# Branching on variable x23
#
# ----------------------------------------------------
#
# Node: 80, Depth: 8, LB: None
# Branching variables: x37 x39 x29 x26 x20 x15 x2 x9
# LP Solved, status: Optimal, obj: 289.3920427
# Fractional solution:
# x1 = 2.5019015
# x3 = 2.6565774
# x6 = 3.0
# x7 = 1.7222222
# x9 = 1.0
# x14 = 3.0
# x16 = 2.537037
# x17 = 1.2135417
# x19 = 0.35416667
# x21 = 2.871875
# x23 = 0.92395833
# x27 = 3.0
# x28 = 3.0
# x30 = 2.9984788
# x32 = 3.0
# x33 = 1.722619
# x37 = 1.0
# x38 = 2.4444444
# x39 = 2.0
# Branching on variable x23
#
# ----------------------------------------------------
#
# Node: 185, Depth: 9, LB: None
# Branching variables: x23 x37 x39 x29 x26 x20 x15 x2 x9
# LP Solved, status: Optimal, obj: 289.22690317999997
# Fractional solution:
# x1 = 2.955555
# x3 = 2.6064182
# x6 = 3.0
# x7 = 1.9489303
# x9 = 1.0
# x14 = 3.0
# x16 = 2.5734223
# x17 = 1.3623188
# x19 = 0.26915114
# x21 = 2.7826087
# x23 = 1.0
# x27 = 2.7984817
# x28 = 3.0
# x30 = 2.8370743
# x32 = 3.0
# x33 = 1.7339545
# x37 = 1.0
# x38 = 2.4444444
# x39 = 2.0
# Branching on variable x19
#
# ----------------------------------------------------
#
# Node: 186, Depth: 10, LB: None
# Branching variables: x19 x23 x37 x39 x29 x26 x20 x15 x2 x9
# LP Solved, status: Optimal, obj: 288.68055462999996
# Fractional solution:
# x1 = 2.5562169
# x3 = 2.6333333
# x6 = 3.0
# x7 = 1.7222222
# x9 = 1.0
# x12 = 0.28333333
# x14 = 3.0
# x16 = 2.537037
# x17 = 1.8333333
# x21 = 2.5
# x23 = 1.0
# x27 = 3.0
# x28 = 3.0
# x30 = 2.9550265
# x32 = 3.0
# x33 = 1.6666667
# x37 = 1.0
# x38 = 2.4444444
# x39 = 2.0
# Branching on variable x12
#
# ----------------------------------------------------
#
# Node: 188, Depth: 11, LB: None
# Branching variables: x12 x19 x23 x37 x39 x29 x26 x20 x15 x2 x9
# LP Solved, status: Optimal, obj: 288.436878
# Fractional solution:
# x1 = 3.0
# x3 = 2.6333333
# x6 = 3.0
# x7 = 1.9741621
# x9 = 1.0
# x14 = 3.0
# x16 = 2.5774718
# x17 = 1.8333333
# x21 = 2.5
# x23 = 1.0
# x27 = 2.7760534
# x28 = 3.0
# x30 = 2.8239466
# x32 = 3.0
# x33 = 1.6666667
# x37 = 1.0
# x38 = 2.4444444
# x39 = 2.0
# Branching on variable x3
#
# ----------------------------------------------------
#
# Node: 191, Depth: 12, LB: None
# Branching variables: x3 x12 x19 x23 x37 x39 x29 x26 x20 x15 x2 x9
# LP Solved, status: Optimal, obj: 287.8868781
# Fractional solution:
# x1 = 3.0
# x3 = 3.0
# x6 = 3.0
# x7 = 1.9741621
# x9 = 1.0
# x14 = 3.0
# x16 = 2.5774718
# x17 = 1.8333333
# x21 = 2.5
# x23 = 1.0
# x27 = 2.7760534
# x28 = 3.0
# x30 = 2.8239466
# x32 = 3.0
# x33 = 0.75
# x37 = 1.0
# x38 = 2.4444444
# x39 = 2.0
# Branching on variable x33
#
# ----------------------------------------------------
#
# Node: 166, Depth: 14, LB: None
# Branching variables: x1 x4 x35 x0 x7 x3 x26 x20 x13 x2 x23 x39 x37 x9
# LP Solved, status: Optimal, obj: 287.57403193000005
# Fractional solution:
# x1 = 2.0
# x3 = 3.0
# x6 = 3.0
# x7 = 1.0
# x10 = 0.14719037
# x14 = 3.0
# x15 = 3.0
# x16 = 2.7777778
# x17 = 1.8501529
# x18 = 0.026299694
# x21 = 2.9899083
# x23 = 1.0
# x25 = 0.09138634
# x27 = 3.0
# x28 = 3.0
# x30 = 3.0
# x32 = 3.0
# x33 = 1.6814602
# x38 = 2.9332314
# x39 = 1.0
# Branching on variable x25
#
# ----------------------------------------------------
#
# Node: 5, Depth: 2, LB: None
# Branching variables: x2 x9
# LP Solved, status: Optimal, obj: 290.41312752
# Fractional solution:
# x0 = 0.23376356
# x1 = 3.0
# x2 = 1.0
# x3 = 3.0
# x6 = 3.0
# x7 = 1.9137916
# x9 = 1.0
# x14 = 3.0
# x15 = 0.27405726
# x16 = 2.5178836
# x17 = 0.84415763
# x21 = 3.0
# x23 = 1.2390762
# x27 = 2.9195345
# x28 = 2.1146509
# x30 = 2.6804655
# x32 = 3.0
# x33 = 1.5728714
# x37 = 2.3089137
# x38 = 2.2827714
# Branching on variable x17
#
# ----------------------------------------------------
#
# Node: 197, Depth: 3, LB: None
# Branching variables: x17 x2 x9
# LP Solved, status: Optimal, obj: 290.33490062000004
# Fractional solution:
# x1 = 3.0
# x2 = 1.0
# x3 = 3.0
# x6 = 3.0
# x7 = 1.983112
# x9 = 1.0
# x14 = 2.9243041
# x16 = 2.5113981
# x17 = 1.0
# x21 = 3.0
# x23 = 1.2580961
# x27 = 2.8896161
# x28 = 2.0922121
# x30 = 2.7103839
# x32 = 3.0
# x33 = 1.5555556
# x37 = 2.4170988
# x38 = 2.2257117
# x39 = 0.03274303
# Branching on variable x39
#
# ----------------------------------------------------
#
# Node: 198, Depth: 4, LB: None
# Branching variables: x39 x17 x2 x9
# LP Solved, status: Optimal, obj: 290.2853396
# Fractional solution:
# x1 = 3.0
# x2 = 1.0
# x3 = 3.0
# x6 = 3.0
# x7 = 1.9972183
# x9 = 1.0
# x14 = 2.950903
# x16 = 2.4971664
# x17 = 1.0
# x21 = 3.0
# x23 = 1.2917663
# x27 = 2.9067694
# x28 = 2.1050771
# x30 = 2.6932306
# x32 = 2.9796151
# x33 = 1.5623505
# x37 = 2.4530605
# x38 = 2.1722657
# Branching on variable x28
#
# ----------------------------------------------------
#
# Node: 200, Depth: 5, LB: None
# Branching variables: x28 x39 x17 x2 x9
# LP Solved, status: Optimal, obj: 290.19772889999996
# Fractional solution:
# x1 = 3.0
# x2 = 1.0
# x3 = 3.0
# x6 = 3.0
# x7 = 1.7567334
# x9 = 1.0
# x14 = 2.7306423
# x15 = 1.3548629
# x16 = 2.6551629
# x17 = 1.0
# x21 = 3.0
# x23 = 1.0689537
# x27 = 2.7666667
# x28 = 2.0
# x30 = 2.8333333
# x32 = 2.9931054
# x33 = 1.5578538
# x37 = 1.7665007
# x38 = 2.8092265
# Branching on variable x23
#
# ----------------------------------------------------
#
# Node: 202, Depth: 6, LB: None
# Branching variables: x23 x28 x39 x17 x2 x9
# LP Solved, status: Optimal, obj: 290.1254533875
# Fractional solution:
# x1 = 3.0
# x2 = 1.0
# ...
# LP Solved, status: Optimal, obj: 281.29050553999997
# Fractional solution:
# x1 = 3.0
# x3 = 2.7167347
# x6 = 3.0
# x7 = 2.0
# x14 = 3.0
# x15 = 3.0
# x16 = 2.25
# x17 = 2.0
# x20 = 1.0
# x21 = 2.9
# x23 = 2.0
# x27 = 2.8148148
# x28 = 2.4285714
# x30 = 2.4285714
# x32 = 2.0142857
# x33 = 2.7081633
# x34 = 0.26759259
# x37 = 1.0
# x38 = 2.3333333
# Branching on variable x34
#
# ----------------------------------------------------
#
# Node: 2495, Depth: 18, LB: 281.0
# Branching variables: x30 x16 x1 x26 x20 x10 x7 x37 x3 x18 x4 x25 x23 x28 x39 x17 x2 x9
# LP Solved, status: Infeasible
# Infeasible node
#
# ----------------------------------------------------
#
# Node: 1035, Depth: 15, LB: 281.0
# Branching variables: x25 x4 x35 x18 x0 x13 x7 x26 x29 x23 x20 x2 x39 x37 x9
# LP Solved, status: Optimal, obj: 283.23888868
# Fractional solution:
# x1 = 1.5198413
# x3 = 3.0
# x6 = 3.0
# x7 = 1.0
# x12 = 0.1
# x14 = 3.0
# x15 = 3.0
# x16 = 2.7777778
# x17 = 1.8333333
# x21 = 3.0
# x22 = 0.16666667
# x23 = 1.0
# x25 = 1.0
# x27 = 3.0
# x28 = 3.0
# x30 = 1.984127
# x32 = 3.0
# x33 = 2.2407407
# x37 = 1.0
# x38 = 2.3333333
# Branching on variable x22
#
# ----------------------------------------------------
#
# Node: 6940, Depth: 16, LB: 281.0
# Branching variables: x22 x25 x4 x35 x18 x0 x13 x7 x26 x29 x23 x20 x2 x39 x37 x9
# LP Solved, status: Optimal, obj: 283.16269818899997
# Fractional solution:
# x1 = 1.5198413
# x3 = 3.0
# x6 = 3.0
# x7 = 1.0
# x12 = 0.023809524
# x14 = 3.0
# x15 = 3.0
# x16 = 2.7777778
# x17 = 1.8333333
# x19 = 0.095238095
# x21 = 3.0
# x23 = 1.0
# x25 = 1.0
# x27 = 3.0
# x28 = 3.0
# x30 = 1.984127
# x32 = 3.0
# x33 = 2.2407407
# x37 = 1.0
# x38 = 2.3333333
# Branching on variable x19
#
# ----------------------------------------------------
#
# Node: 6942, Depth: 17, LB: 281.0
# Branching variables: x19 x22 x25 x4 x35 x18 x0 x13 x7 x26 x29 x23 x20 x2 x39 x37 x9
# LP Solved, status: Optimal, obj: 282.9690475
# Fractional solution:
# x1 = 1.5198413
# x3 = 3.0
# x6 = 3.0
# x7 = 1.0
# x12 = 0.1
# x14 = 3.0
# x15 = 3.0
# x16 = 2.7777778
# x17 = 1.8333333
# x21 = 3.0
# x23 = 1.0
# x25 = 1.0
# x27 = 3.0
# x28 = 2.8571429
# x30 = 1.984127
# x32 = 3.0
# x33 = 2.2407407
# x37 = 1.0
# x38 = 2.4444444
# Branching on variable x12
#
# ----------------------------------------------------
#
# Node: 6944, Depth: 18, LB: 281.0
# Branching variables: x12 x19 x22 x25 x4 x35 x18 x0 x13 x7 x26 x29 x23 x20 x2 x39 x37 x9
# LP Solved, status: Optimal, obj: 282.86904749999997
# Fractional solution:
# x1 = 1.5198413
# x3 = 3.0
# x6 = 3.0
# x7 = 1.0
# x14 = 3.0
# x15 = 3.0
# x16 = 2.7777778
# x17 = 1.8333333
# x21 = 3.0
# x23 = 1.0
# x25 = 1.0
# x27 = 3.0
# x28 = 2.8571429
# x30 = 1.984127
# x32 = 3.0
# x33 = 2.2407407
# x37 = 1.0
# x38 = 2.4444444
# Branching on variable x1
#
# ----------------------------------------------------
#
# Node: 6947, Depth: 19, LB: 281.0
# Branching variables: x1 x12 x19 x22 x25 x4 x35 x18 x0 x13 x7 x26 x29 x23 x20 x2 x39 x37 x9
# LP Solved, status: Optimal, obj: 282.0186451
# Fractional solution:
# x1 = 2.0
# x3 = 3.0
# x6 = 3.0
# x7 = 1.0
# x14 = 3.0
# x15 = 3.0
# x16 = 2.939759
# x17 = 1.8333333
# x21 = 3.0
# x23 = 1.0
# x25 = 1.0
# x27 = 2.7084337
# x28 = 2.8571429
# x30 = 1.8915663
# x32 = 3.0
# x33 = 2.2407407
# x37 = 1.0
# x38 = 2.4444444
# Branching on variable x17
#
# ----------------------------------------------------
#
# Node: 6949, Depth: 20, LB: 281.0
# Branching variables: x17 x1 x12 x19 x22 x25 x4 x35 x18 x0 x13 x7 x26 x29 x23 x20 x2 x39 x37 x9
# LP Solved, status: Optimal, obj: 281.9662643
# Fractional solution:
# x1 = 2.0
# x3 = 3.0
# x6 = 3.0
# x7 = 1.0
# x14 = 3.0
# x15 = 3.0
# x16 = 2.939759
# x17 = 2.0
# x21 = 2.9
# x23 = 1.0
# x25 = 1.0
# x27 = 2.7084337
# x28 = 3.0
# x30 = 1.8915663
# x32 = 3.0
# x33 = 2.2222222
# x37 = 1.0
# x38 = 2.3333333
# Branching on variable x16
#
# ----------------------------------------------------
#
# Node: 6951, Depth: 21, LB: 281.0
# Branching variables: x16 x17 x1 x12 x19 x22 x25 x4 x35 x18 x0 x13 x7 x26 x29 x23 x20 x2 x39 x37 x9
# LP Solved, status: Optimal, obj: 281.292857128
# Fractional solution:
# x1 = 2.0
# x3 = 3.0
# x6 = 3.0
# x7 = 1.0
# x10 = 0.089285714
# x14 = 3.0
# x15 = 3.0
# x16 = 3.0
# x17 = 2.0
# x21 = 2.9
# x23 = 1.0
# x25 = 1.0
# x27 = 2.6
# x28 = 3.0
# x30 = 1.8571429
# x32 = 3.0
# x33 = 2.2222222
# x37 = 1.0
# x38 = 2.3333333
# Branching on variable x10
#
# ----------------------------------------------------
#
# Node: 6946, Depth: 19, LB: 281.0
# Branching variables: x1 x12 x19 x22 x25 x4 x35 x18 x0 x13 x7 x26 x29 x23 x20 x2 x39 x37 x9
# LP Solved, status: Optimal, obj: 282.4323804
# Fractional solution:
# x1 = 1.0
# x3 = 3.0
# x6 = 3.0
# x7 = 1.0
# x14 = 3.0
# x15 = 3.0
# x16 = 2.05
# x17 = 1.8333333
# x21 = 3.0
# x23 = 1.0
# x25 = 1.0
# x27 = 3.0
# x28 = 2.8571429
# x30 = 2.4
# x32 = 3.0
# x33 = 2.2407407
# x34 = 0.655
# x37 = 1.0
# x38 = 2.4444444
# Branching on variable x34
#
# ----------------------------------------------------
#
# Node: 6954, Depth: 20, LB: 281.0
# Branching variables: x34 x1 x12 x19 x22 x25 x4 x35 x18 x0 x13 x7 x26 x29 x23 x20 x2 x39 x37 x9
# LP Solved, status: Optimal, obj: 281.82936486
# Fractional solution:
# x1 = 1.0
# x3 = 3.0
# x6 = 3.0
# x7 = 1.0
# x10 = 0.25992063
# x14 = 3.0
# x15 = 3.0
# x16 = 2.7777778
# x17 = 1.8333333
# x21 = 3.0
# x23 = 1.0
# x25 = 1.0
# x27 = 3.0
# x28 = 2.8571429
# x30 = 1.984127
# x32 = 3.0
# x33 = 2.2407407
# x37 = 1.0
# x38 = 2.4444444
# Branching on variable x10
#
# ----------------------------------------------------
#
# Node: 6956, Depth: 21, LB: 281.0
# Branching variables: x10 x34 x1 x12 x19 x22 x25 x4 x35 x18 x0 x13 x7 x26 x29 x23 x20 x2 x39 x37 x9
# LP Solved, status: Optimal, obj: 281.67839038
# Fractional solution:
# x1 = 1.0
# x3 = 3.0
# x6 = 3.0
# x7 = 1.0
# x14 = 3.0
# x15 = 3.0
# x16 = 2.3611111
# x17 = 1.8333333
# x21 = 3.0
# x23 = 1.0
# x24 = 0.14141414
# x25 = 1.0
# x27 = 3.0
# x28 = 2.8571429
# x30 = 2.2020202
# x32 = 3.0
# x33 = 2.2407407
# x36 = 1.875
# x37 = 1.0
# x38 = 2.4444444
# Branching on variable x24
#
# ----------------------------------------------------
#
# Node: 6958, Depth: 22, LB: 281.0
# Branching variables: x24 x10 x34 x1 x12 x19 x22 x25 x4 x35 x18 x0 x13 x7 x26 x29 x23 x20 x2 x39 x37 x9
# LP Solved, status: Optimal, obj: 281.5773801
# Fractional solution:
# x1 = 1.0
# x3 = 3.0
# x6 = 3.0
# x7 = 1.0
# x14 = 3.0
# x15 = 3.0
# x16 = 2.3611111
# x17 = 1.8333333
# x21 = 3.0
# x23 = 1.0
# x25 = 1.0
# x27 = 3.0
# x28 = 2.8571429
# x30 = 2.2222222
# x32 = 3.0
# x33 = 2.2407407
# x36 = 1.875
# x37 = 1.0
# x38 = 2.4444444
# Branching on variable x17
#
# ----------------------------------------------------
#
# Node: 6961, Depth: 23, LB: 281.0
# Branching variables: x17 x24 x10 x34 x1 x12 x19 x22 x25 x4 x35 x18 x0 x13 x7 x26 x29 x23 x20 x2 x39 x37 x9
# LP Solved, status: Optimal, obj: 281.52499930000005
# Fractional solution:
# x1 = 1.0
# x3 = 3.0
# x6 = 3.0
# x7 = 1.0
# x14 = 3.0
# x15 = 3.0
# x16 = 2.3611111
# x17 = 2.0
# x21 = 2.9
# x23 = 1.0
# x25 = 1.0
# x27 = 3.0
# x28 = 3.0
# x30 = 2.2222222
# x32 = 3.0
# x33 = 2.2222222
# x36 = 1.875
# x37 = 1.0
# x38 = 2.3333333
# Branching on variable x16
#
# ----------------------------------------------------
#
# Node: 6963, Depth: 24, LB: 281.0
# Branching variables: x16 x17 x24 x10 x34 x1 x12 x19 x22 x25 x4 x35 x18 x0 x13 x7 x26 x29 x23 x20 x2 x39 x37 x9
# LP Solved, status: Optimal, obj: 278.11428570000004
# Fractional solution:
# x1 = 1.0
# x3 = 3.0
# x6 = 3.0
# x7 = 1.0
# x14 = 3.0
# x15 = 3.0
# x16 = 3.0
# x17 = 2.0
# x21 = 2.9
# x23 = 1.0
# x25 = 1.0
# x27 = 2.6
# x28 = 3.0
# x30 = 1.8571429
# x32 = 3.0
# x33 = 2.2222222
# x37 = 1.0
# x38 = 2.3333333
# Node pruned by bound (obj: 278.11428570000004, UB: 281.0)
#
# ----------------------------------------------------
#
# Node: 6242, Depth: 26, LB: 281.0
# Branching variables: x35 x4 x11 x16 x22 x24 x36 x28 x10 x34 x5 x7 x17 x12 x13 x19 x18 x23 x33 x39 x29 x26 x20 x15 x2 x9
# LP Solved, status: Optimal, obj: 281.3864095
# Fractional solution:
# x1 = 2.6155754
# x3 = 3.0
# x6 = 3.0
# x7 = 2.0
# x9 = 1.0
# x14 = 3.0
# x16 = 2.0
# x17 = 1.0
# x21 = 3.0
# x23 = 1.0
# x25 = 0.125
# x27 = 2.6825397
# x28 = 2.0
# x30 = 3.0
# x32 = 3.0
# x33 = 1.0
# x36 = 1.0
# x37 = 1.8571429
# x38 = 2.5714286
# x39 = 1.0
# Branching on variable x25
#
# ----------------------------------------------------
#
# Node: 5012, Depth: 16, LB: 281.0
# Branching variables: x16 x21 x15 x17 x36 x10 x34 x7 x26 x29 x23 x20 x2 x39 x37 x9
# LP Solved, status: Optimal, obj: 280.8666668
# Fractional solution:
# x0 = 1.9
# x1 = 3.0
# x3 = 3.0
# x6 = 3.0
# x7 = 2.0
# x14 = 3.0
# x15 = 3.0
# x16 = 2.0
# x17 = 2.0
# x21 = 2.0
# x22 = 0.5
# x23 = 1.0
# x27 = 3.0
# x28 = 3.0
# x30 = 2.6
# x32 = 2.75
# x33 = 2.3055556
# x36 = 1.0
# x37 = 1.0
# x38 = 2.0
# Node pruned by bound (obj: 280.8666668, UB: 281.0)
#
# ----------------------------------------------------
#
# Node: 3634, Depth: 23, LB: 281.0
# Branching variables: x10 x16 x25 x4 x35 x0 x34 x5 x7 x17 x12 x13 x19 x18 x23 x33 x39 x29 x26 x20 x15 x2 x9
# LP Solved, status: Optimal, obj: 280.96039194
# Fractional solution:
# x1 = 3.0
# x3 = 3.0
# x6 = 3.0
# x7 = 2.0
# x9 = 1.0
# x14 = 3.0
# x16 = 2.0
# x17 = 1.0
# x21 = 2.9666667
# x23 = 1.0
# x27 = 1.8
# x28 = 2.7047059
# x30 = 3.0
# x31 = 0.16666667
# x32 = 3.0
# x33 = 1.0
# x34 = 1.0
# x37 = 1.6517647
# x38 = 2.6741176
# x39 = 1.0
# Node pruned by bound (obj: 280.96039194, UB: 281.0)
#
# ----------------------------------------------------
#
# Node: 2526, Depth: 15, LB: 281.0
# Branching variables: x16 x23 x5 x3 x1 x17 x7 x37 x39 x29 x26 x20 x15 x2 x9
# LP Solved, status: Optimal, obj: 281.97334385
# Fractional solution:
# x0 = 1.3920455
# x1 = 3.0
# x3 = 2.0
# x4 = 0.16582792
# x6 = 3.0
# x7 = 1.0
# x9 = 1.0
# x14 = 3.0
# x16 = 2.0
# x17 = 1.0
# x18 = 0.47585227
# x21 = 2.4431818
# x23 = 1.0
# x27 = 3.0
# x28 = 2.7926136
# x30 = 2.6
# x32 = 2.75
# x33 = 1.8243371
# x34 = 0.65025162
# x37 = 2.0
# x38 = 2.5
# x39 = 2.0
# Branching on variable x34
#
# ----------------------------------------------------
#
# Node: 6966, Depth: 16, LB: 281.0
# Branching variables: x34 x16 x23 x5 x3 x1 x17 x7 x37 x39 x29 x26 x20 x15 x2 x9
# LP Solved, status: Optimal, obj: 280.384482609
# Fractional solution:
# x1 = 3.0
# x3 = 2.0
# x4 = 0.94827586
# x6 = 3.0
# x7 = 1.0
# x9 = 1.0
# x11 = 0.040517241
# x14 = 3.0
# x16 = 2.0
# x17 = 1.0
# x21 = 3.0
# x23 = 1.0
# x27 = 3.0
# x28 = 2.375
# x30 = 2.6
# x32 = 2.7246767
# x33 = 2.1848779
# x36 = 1.875
# x37 = 2.0
# x38 = 2.5
# x39 = 2.0
# Node pruned by bound (obj: 280.384482609, UB: 281.0)
#
# ----------------------------------------------------
#
# Node: 6610, Depth: 18, LB: 281.0
# Branching variables: x4 x1 x7 x17 x11 x16 x26 x12 x36 x10 x34 x29 x20 x39 x22 x15 x2 x9
# LP Solved, status: Optimal, obj: 281.4033669
# Fractional solution:
# x1 = 3.0
# x3 = 3.0
# x6 = 3.0
# x7 = 2.0
# x9 = 1.0
# x13 = 0.13208643
# x14 = 2.469328
# x15 = 1.0
# x16 = 2.0
# x17 = 3.0
# x21 = 1.7075395
# x22 = 1.0
# x23 = 1.6858271
# x27 = 3.0
# x28 = 3.0
# x30 = 2.6
# x32 = 3.0
# x33 = 1.3333333
# x36 = 1.0
# x37 = 1.668448
# x38 = 1.3733388
# Branching on variable x13
#
# ----------------------------------------------------
#
# Node: 5819, Depth: 26, LB: 281.0
# Branching variables: x37 x28 x5 x7 x8 x11 x36 x34 x16 x18 x24 x17 x31 x4 x35 x25 x22 x23 x10 x1 x29 x26 x20 x15 x2 x9
# LP Solved, status: Optimal, obj: 277.66666660000004
# Fractional solution:
# x0 = 0.5
# x3 = 3.0
# x6 = 3.0
# x7 = 2.0
# x9 = 1.0
# x14 = 3.0
# x16 = 2.0
# x17 = 1.0
# x21 = 2.8
# x23 = 1.0
# x27 = 3.0
# x28 = 2.0
# x29 = 1.0
# x30 = 3.0
# x32 = 2.5
# x33 = 1.7222222
# x37 = 3.0
# x38 = 1.72
# Node pruned by bound (obj: 277.66666660000004, UB: 281.0)
#
# ----------------------------------------------------
#
# Node: 6477, Depth: 22, LB: 281.0
# Branching variables: x30 x35 x11 x16 x1 x3 x17 x12 x7 x34 x4 x0 x15 x18 x29 x13 x26 x20 x23 x39 x37 x9
# LP Solved, status: Optimal, obj: 282.59000000000003
# Fractional solution:
# x1 = 3.0
# x3 = 3.0
# x4 = 1.0
# x6 = 3.0
# x7 = 1.0
# x14 = 2.605
# x15 = 2.0
# x16 = 1.0
# x17 = 2.0
# x21 = 2.9
# x23 = 1.0
# x27 = 2.6
# x28 = 3.0
# x30 = 3.0
# x32 = 3.0
# x33 = 2.0
# x34 = 1.0
# x36 = 1.145
# x37 = 1.0
# x38 = 2.86
# x39 = 1.0
# Branching on variable x27
#
# ----------------------------------------------------
#
# Node: 6971, Depth: 23, LB: 281.0
# Branching variables: x27 x30 x35 x11 x16 x1 x3 x17 x12 x7 x34 x4 x0 x15 x18 x29 x13 x26 x20 x23 x39 x37 x9
# LP Solved, status: Infeasible
# Infeasible node
#
# ----------------------------------------------------
#
# Node: 6810, Depth: 17, LB: 281.0
# Branching variables: x31 x10 x0 x35 x25 x13 x16 x34 x29 x20 x37 x33 x39 x22 x15 x2 x9
# LP Solved, status: Optimal, obj: 281.1754102
# Fractional solution:
# x1 = 3.0
# x3 = 2.245974
# x6 = 3.0
# x7 = 1.1437229
# x9 = 1.0
# x14 = 3.0
# x15 = 1.0
# x16 = 2.0
# x17 = 1.6818182
# x21 = 2.5909091
# x23 = 1.6
# x27 = 2.3137662
# x28 = 3.0
# x30 = 3.0
# x32 = 2.6961039
# x33 = 2.0
# x34 = 1.0
# x37 = 2.0
# x38 = 2.0454545
# x39 = 1.0
# Branching on variable x7
#
# ----------------------------------------------------
#
# Node: 5822, Depth: 16, LB: 281.0
# Branching variables: x25 x16 x29 x36 x10 x17 x34 x26 x20 x37 x33 x39 x22 x15 x2 x9
# LP Solved, status: Optimal, obj: 281.28038119999997
# Fractional solution:
# x1 = 3.0
# x3 = 2.3984375
# x6 = 3.0
# x7 = 2.1041667
# x9 = 1.0
# x14 = 3.0
# x15 = 1.0
# x16 = 2.0
# x17 = 2.0
# x20 = 1.0
# x21 = 2.4
# x23 = 1.9720486
# x27 = 3.0
# x28 = 2.3429315
# x30 = 2.5427579
# x32 = 2.3359375
# x33 = 2.0
# x37 = 2.0
# x38 = 1.8333333
# x39 = 1.0
# Branching on variable x3
#
# ----------------------------------------------------
#
# Node: 1984, Depth: 15, LB: 281.0
# Branching variables: x33 x28 x18 x29 x10 x7 x13 x0 x3 x23 x17 x2 x39 x37 x9
# LP Solved, status: Optimal, obj: 281.61691945999996
# Fractional solution:
# x0 = 1.0
# x1 = 3.0
# x2 = 1.0
# x3 = 3.0
# x4 = 0.17877936
# x6 = 3.0
# x7 = 2.0
# x14 = 3.0
# x15 = 2.1175341
# x16 = 2.5365388
# x17 = 1.0
# x19 = 0.19123294
# x21 = 3.0
# x22 = 0.178141
# x23 = 1.0
# x25 = 0.76279863
# x27 = 2.7269625
# x28 = 3.0
# x30 = 1.5
# x32 = 3.0
# x37 = 1.0
# x38 = 2.4914676
# Branching on variable x25
#
# ----------------------------------------------------
#
# Node: 3590, Depth: 15, LB: 281.0
# Branching variables: x10 x16 x7 x17 x19 x22 x12 x13 x26 x2 x18 x23 x39 x37 x9
# LP Solved, status: Optimal, obj: 281.30043245999997
# Fractional solution:
# x1 = 3.0
# x3 = 3.0
# x6 = 3.0
# x7 = 1.0
# x14 = 3.0
# x15 = 3.0
# x16 = 3.0
# x17 = 2.0
# x18 = 1.0
# x21 = 2.9
# x24 = 0.22727273
# x27 = 2.6
# x28 = 2.9285714
# x30 = 2.6818182
# x32 = 3.0
# x33 = 1.4444444
# x38 = 2.8333333
# x39 = 1.0
# Branching on variable x24
#
# ----------------------------------------------------
#
# Node: 4620, Depth: 20, LB: 281.0
# Branching variables: x37 x16 x22 x24 x26 x15 x7 x36 x20 x10 x29 x34 x4 x25 x23 x28 x39 x17 x2 x9
# LP Solved, status: Optimal, obj: 281.226190601
# Fractional solution:
# x1 = 3.0
# x2 = 1.0
# x3 = 3.0
# x4 = 1.0
# x6 = 3.0
# x7 = 2.0
# x9 = 1.0
# x11 = 0.1
# x12 = 0.021428571
# x14 = 3.0
# x16 = 2.0
# x17 = 1.0
# x19 = 0.28571429
# x21 = 3.0
# x23 = 1.0
# x27 = 3.0
# x28 = 2.0
# x30 = 2.0857143
# x32 = 3.0
# x33 = 1.5111111
# x37 = 2.0
# x38 = 2.0
# Branching on variable x19
#
# ----------------------------------------------------
#
# Node: 4609, Depth: 9, LB: 281.0
# Branching variables: x16 x26 x20 x13 x2 x23 x39 x37 x9
# LP Solved, status: Optimal, obj: 277.9032806
# Fractional solution:
# x1 = 3.0
# x3 = 2.5355685
# x6 = 3.0
# x7 = 1.0
# x14 = 3.0
# x15 = 3.0
# x16 = 3.0
# x17 = 2.0714286
# x21 = 2.8571429
# x23 = 1.0
# x26 = 1.0
# x27 = 2.6
# x28 = 1.875
# x30 = 3.0
# x32 = 1.6836735
# x33 = 2.9110787
# x38 = 2.7857143
# x39 = 1.0
# Node pruned by bound (obj: 277.9032806, UB: 281.0)
#
# ----------------------------------------------------
#
# Node: 5950, Depth: 18, LB: 281.0
# Branching variables: x11 x16 x22 x25 x4 x35 x0 x13 x34 x7 x26 x29 x23 x20 x2 x39 x37 x9
# LP Solved, status: Optimal, obj: 281.4925924
# Fractional solution:
# x1 = 1.0171958
# x3 = 3.0
# x6 = 3.0
# x7 = 2.0
# x14 = 3.0
# x15 = 2.5
# x16 = 1.0
# x17 = 2.0
# x21 = 2.9
# x23 = 1.0
# x25 = 1.0
# x27 = 2.8148148
# x28 = 3.0
# x30 = 2.5714286
# x32 = 3.0
# x33 = 2.2222222
# x34 = 1.0
# x36 = 0.75
# x37 = 1.0
# x38 = 2.3333333
# Branching on variable x36
#
# ----------------------------------------------------
#
# Node: 6547, Depth: 27, LB: 281.0
# Branching variables: x28 x35 x4 x18 x8 x11 x16 x10 x5 x34 x7 x17 x22 x13 x33 x3 x12 x19 x23 x37 x39 x29 x26 x20 x15 x2 x9
# LP Solved, status: Optimal, obj: 281.276234
# Fractional solution:
# x1 = 2.808642
# x3 = 3.0
# x6 = 3.0
# x7 = 2.0
# x9 = 1.0
# x14 = 3.0
# x16 = 2.0
# x17 = 1.0
# x21 = 3.0
# x23 = 1.0
# x27 = 2.7530864
# x28 = 3.0
# x30 = 3.0
# x32 = 3.0
# x36 = 1.875
# x37 = 1.0
# x38 = 2.4444444
# x39 = 2.0
# Branching on variable x1
#
# ----------------------------------------------------
#
# Node: 5676, Depth: 14, LB: 281.0
# Branching variables: x7 x3 x11 x16 x29 x36 x10 x34 x23 x20 x2 x39 x37 x9
# LP Solved, status: Optimal, obj: 281.5428574
# Fractional solution:
# x1 = 3.0
# x3 = 3.0
# x6 = 3.0
# x7 = 2.0
# x14 = 3.0
# x15 = 3.0
# x16 = 2.0
# x17 = 2.5
# x21 = 2.6
# x23 = 2.0
# x27 = 3.0
# x28 = 3.0
# x30 = 2.5714286
# x32 = 2.2
# x33 = 2.0
# x37 = 1.0
# x38 = 2.0
# Branching on variable x17
#
# ----------------------------------------------------
#
# Node: 6987, Depth: 15, LB: 281.0

# %%
T = BBTree()
opt1, LB1,stat1 = BranchAndBound(T, CONSTRAINTS, VARIABLES, OBJ,MAT, RHS,branch_strategy=PSEUDOCOST_BRANCHING,search_strategy=BEST_ESTIMATE,more_return = True,binary_vars = False)

# %%
print(LB1)
print(stat1)

# %%
# %%capture
T = BBTree()
opt2, LB2,stat2 = BranchAndBound(T, CONSTRAINTS, VARIABLES, OBJ,MAT, RHS,branch_strategy= RELIABILITY_BRANCHING,search_strategy=BEST_ESTIMATE,more_return = True,binary_vars = False)

# %%
print(LB2)
print(stat2)

# %%
# %%capture
T = BBTree()
opt3, LB3,stat3 = BranchAndBound(T, CONSTRAINTS, VARIABLES, OBJ,MAT, RHS,branch_strategy=  HYBRID,search_strategy=BEST_ESTIMATE,more_return = True,binary_vars = False)

# %%
print(LB3)
print(stat3)

# %%
# %%capture
# input Parameters 
M = 10  # Number of Problems
seed(27)



##################################################
branch= [MOST_FRACTIONAL, FIXED_BRANCHING, PSEUDOCOST_BRANCHING,RELIABILITY_BRANCHING,HYBRID]
search = [DEPTH_FIRST, BEST_FIRST, BEST_ESTIMATE]
prob_data = np.array([]) # Record type of problems
costs_node = {i + ' - ' + j:np.array([]) for i in branch for j in search}
costs_time = {i + ' - ' + j:np.array([]) for i in branch for j in search}

# Solve problems and record tree size of costs
for k in range(M):
    # Problem Size will be random
    numVars = randint(4,16)
    numCons = randint(int(numVars/4),numVars)
    rand_seed = randint(1,200)
    #prob_data = np.append(prob_data,(numVars,numCons,rand_seed))
    CONSTRAINTS, VARIABLES, OBJ, MAT, RHS = GenerateRandomMIP(
        numVars=numVars , numCons=numCons,rand_seed= rand_seed)
    for i in branch:
        for j in search:
            T = BBTree()
            opt, LB,stat = BranchAndBound(
                T, CONSTRAINTS, VARIABLES, OBJ,MAT, RHS,branch_strategy=i,search_strategy=j,more_return = True)
            if LB>-INFINITY:
                costs_node[i + ' - ' + j] = np.append(costs_node[i + ' - ' + j],int(stat['Size']))
                costs_time[i + ' - ' + j] = np.append(costs_time[i + ' - ' + j],float(stat['Time']))
            else:
                costs_node[i + ' - ' + j] = np.append(costs_node[i + ' - ' + j],INFINITY)

# %%
def performance_profile(costs,name):
    # Do some computations
    # Calculate Minimum Cost of Each Problem
    min_costs = np.ones(M)*math.inf
    for i in branch:
        for j in search:
            for k in range(M):
                 if costs[i + ' - ' + j][k]<min_costs[k]:
                    min_costs[k] = costs[i + ' - ' + j][k]

    # Calculate Ratio of Each Problem  with Each Method              
    ratios = costs
    for i in branch:
        for j in search:
            for k in range(M):
                ratios[i + ' - ' + j][k] = costs[i + ' - ' + j][k]/min_costs[k]

    # Efficients
    effs = np.zeros(len(branch) * len(search))
    ind = 0
    for rk in ratios.keys():
        effs[ind] = np.sum(ratios[rk]<=1)/M
        ind += 1

    # Robustness    
    rmax = 0
    for rk in ratios.keys():
        if np.max(ratios[rk]) >rmax:
            rmax = np.max(ratios[rk])

    robs = np.zeros(len(branch) * len(search))
    ind = 0
    for rk in ratios.keys():
        robs[ind] = np.sum(ratios[rk]<=rmax)/M
        ind += 1

    # Print a table
    d = {'Method':list(ratios.keys()),'Efficiency':effs,'Robustness':robs}
    df = pd.DataFrame(data=d)
    with open(name + '.tex', 'w') as tf:
         tf.write(df.to_latex(index=False))
            
    # Do plot
    all_rs = np.array([])
    for rk in ratios.keys():
        all_rs = np.append(all_rs,ratios[rk])

    # x-axis
    t = np.sort(np.unique(all_rs))
    for rk in ratios.keys():
        plt.plot(t,[np.sum(ratios[rk]<=t[i])/M for i in range(len(t)) ],label = rk)

    plt.xlabel('Performance Ratio')
    plt.ylabel(name)
    plt.title('Performance Profile')
    plt.legend(bbox_to_anchor=(1.05, 1.0), loc='upper left')
    plt.savefig(name + ' ' + 'Performance_Profile_All')
    plt.show()
    
    
    for i in branch:
        for rk in ratios.keys():
            if i in rk:
                plt.plot(t,[np.sum(ratios[rk]<=t[i])/M for i in range(len(t)) ],label = rk)
        plt.xlabel('Performance Ratio')
        plt.ylabel(name)
        plt.title('Performance Profile')
        plt.legend( loc='lower right')
        plt.savefig(name + ' ' + i)
        plt.show()

    for j in search:
        for rk in ratios.keys():
            if j in rk:
                plt.plot(t,[np.sum(ratios[rk]<=t[i])/M for i in range(len(t)) ],label = rk)
        plt.xlabel('Performance Ratio')
        plt.ylabel(name)
        plt.title('Performance Profile')
        plt.legend(loc='lower right')
        plt.savefig(name + ' ' + j)
        plt.show()

# %%
performance_profile(costs_node, 'Tree Size')
performance_profile(costs_time, 'Solution Time')
